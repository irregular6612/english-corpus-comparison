# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import os

# %%
proj_dir = os.path.join(Path.home(), 'Documents', 'WorkSpace', 'corpus-comparison')
analysis_dir = os.path.join(proj_dir, 'analysis')
corpora_dir = os.path.join(proj_dir, 'corpora')

print(f"Project directory: {proj_dir}")
print(f"Analysis directory: {analysis_dir}")
print(f"Corpora directory: {corpora_dir}")
# Out:
# Project directory: /Users/bagjuhyeon/Documents/WorkSpace/corpus-comparison
# Analysis directory: /Users/bagjuhyeon/Documents/WorkSpace/corpus-comparison/analysis
# Corpora directory: /Users/bagjuhyeon/Documents/WorkSpace/corpus-comparison/corpora

# %%
KE_E_final_df = pd.read_excel(os.path.join(corpora_dir, 'merged_corpora', 'KE_E_final(250927-1500)-zeroIn.xlsx'))
KE_E_final_df
# Out:
#            Word  Freq_KE  Freq_KE(EXAM)  Freq_KE(TEXTBOOK)  Ortho_N_KE  \
# 0             a    17505         9773.0             7732.0         1.0
# 1           aah        0            NaN                NaN         NaN
# 2         aaron        7            1.0                6.0         1.0
# 3         aback        0            NaN                NaN         NaN
# 4        abacus        0            NaN                NaN         NaN
# ...         ...      ...            ...                ...         ...
# 40476      zoom        0            NaN                NaN         NaN
# 40477   zooming        0            NaN                NaN         NaN
# 40478     zooms        0            NaN                NaN         NaN
# 40479  zucchini        0            NaN                NaN         NaN
# 40480    zurich        0            NaN                NaN         NaN
#
#        Ortho_N_KE(EXAM)  Ortho_N_KE(TEXTBOOK)  OLD_KE  OLD_KE(EXAM)  \
# 0                   1.0                   1.0    1.45          1.45
# 1                   NaN                   NaN     NaN           NaN
# 2                   1.0                   0.0    1.85          1.95
# 3                   NaN                   NaN     NaN           NaN
# 4                   NaN                   NaN     NaN           NaN
# ...                 ...                   ...     ...           ...
# 40476               NaN                   NaN     NaN           NaN
# 40477               NaN                   NaN     NaN           NaN
# 40478               NaN                   NaN     NaN           NaN
# 40479               NaN                   NaN     NaN           NaN
# 40480               NaN                   NaN     NaN           NaN
#
#        OLD_KE(TEXTBOOK)  ...  RFreq_HAL(130)  RFreq_HAL(160)  RFreq_SUBTLEX  \
# 0                  1.45  ...    81620.200000     66316.41250       20415.27
# 1                   NaN  ...        1.707692         1.38750          52.71
# 2                  2.00  ...       83.123077        67.53750          14.65
# 3                   NaN  ...        2.976923         2.41875           0.29
# 4                   NaN  ...        3.946154         3.20625           0.24
# ...                 ...  ...             ...             ...            ...
# 40476               NaN  ...       37.846154        30.75000           3.55
# 40477               NaN  ...        4.023077         3.26875           0.63
# 40478               NaN  ...        2.961538         2.40625           0.06
# 40479               NaN  ...        2.415385         1.96250           0.96
# 40480               NaN  ...       13.615385        11.06250           2.43
#
#         Zipf_KE  Zipf_KE(EXAM)  Zipf_KE(TEXTBOOK)   Zipf_KF  Zipf_HAL(130)  \
# 0      7.360356       7.341828           7.371453  7.340727       7.911473
# 1      3.117169            NaN                NaN  3.275558       3.234037
# 2      4.020259       3.652785           4.328203  3.877618       4.919437
# 3      3.117169            NaN                NaN  3.451649       3.474564
# 4      3.117169            NaN                NaN  2.974528       3.596695
# ...         ...            ...                ...       ...            ...
# 40476  3.117169            NaN                NaN  2.974528       4.577785
# 40477  3.117169            NaN                NaN  3.275558       3.605063
# 40478  3.117169            NaN                NaN  3.275558       3.472319
# 40479  3.117169            NaN                NaN  2.974528       3.384042
# 40480  3.117169            NaN                NaN  3.451649       4.133950
#
#        Zipf_HAL(160)  Zipf_SUBTLEX
# 0           7.821357      7.309323
# 1           3.143921      4.721422
# 2           4.829321      4.165786
# 3           3.384448      2.490180
# 4           3.506579      2.413686
# ...              ...           ...
# 40476       4.487669      3.551988
# 40477       3.514947      2.812019
# 40478       3.382203      1.900324
# 40479       3.293927      2.990420
# 40480       4.043835      3.388464
#
# [40481 rows x 57 columns]

# %%
sns.countplot(x='Freq_KE', data=KE_E_final_df)
# Out:
# <Axes: xlabel='Freq_KE', ylabel='count'>

# %%
sns.countplot(x='Freq_SUBTLEX', data=KE_E_final_df)
# Out:
# <Axes: xlabel='Freq_SUBTLEX', ylabel='count'>

# %%
KE_E_final_df['Freq_SUBTLEX'].describe()
# Out:
# count    4.048100e+04
# mean     1.129031e+03
# std      2.234207e+04
# min      0.000000e+00
# 25%      5.100000e+00
# 50%      2.499000e+01
# 75%      1.142400e+02
# max      2.134713e+06
# Name: Freq_SUBTLEX, dtype: float64

# %%
KE_E_final_df.columns
# Out:
# Index(['Word', 'Freq_KE', 'Freq_KE(EXAM)', 'Freq_KE(TEXTBOOK)', 'Ortho_N_KE',
#        'Ortho_N_KE(EXAM)', 'Ortho_N_KE(TEXTBOOK)', 'OLD_KE', 'OLD_KE(EXAM)',
#        'OLD_KE(TEXTBOOK)', 'Length', 'Freq_KF', 'Freq_HAL', 'Freq_SUBTLEX',
#        'SUBTLCD', 'Ortho_N', 'Phono_N', 'OLD', 'PLD', 'Concreteness_Rating',
#        'Semantic_Neighborhood_Density', 'Semantic_Neighbors',
#        'Semantic_Diversity', 'Age_Of_Acquisition', 'Body_Object_Interaction',
#        'Emotional_Valence', 'Emotional_Arousal', 'Emotional_Dominance',
#        'Assoc_Freq_R1', 'Assoc_Types_R1', 'Assoc_Freq_R123',
#        'Assoc_Types_R123', 'POS', 'LDT_RT_MEAN', 'LDT_RT_ZSCORE', 'LDT_RT_SD',
#        'LDT_RT_OBS', 'LDT_ACC_MEAN', 'NMG_RT_MEAN', 'NMG_RT_ZSCORE',
#        'NMG_RT_SD', 'NMG_RT_OBS', 'NMG_ACC_MEAN', 'RFreq_KE', 'RFreq_KE(EXAM)',
#        'RFreq_KE(TEXTBOOK)', 'RFreq_KF', 'RFreq_HAL(130)', 'RFreq_HAL(160)',
#        'RFreq_SUBTLEX', 'Zipf_KE', 'Zipf_KE(EXAM)', 'Zipf_KE(TEXTBOOK)',
#        'Zipf_KF', 'Zipf_HAL(130)', 'Zipf_HAL(160)', 'Zipf_SUBTLEX'],
#       dtype='object')

# %%
# E-lexicon에서 LDT behavior exp results가 있는 단어들.
exp_cols = ['Word', 'Length', 'LDT_RT_MEAN', 'LDT_RT_SD', 'LDT_RT_OBS', 'LDT_ACC_MEAN']
mask = KE_E_final_df[exp_cols].isna().any(axis=1)
ELP_LDT_data = KE_E_final_df[~mask].reset_index(drop=True)

ELP_LDT_data
# Out:
#            Word  Freq_KE  Freq_KE(EXAM)  Freq_KE(TEXTBOOK)  Ortho_N_KE  \
# 0             a    17505         9773.0             7732.0         1.0
# 1           aah        0            NaN                NaN         NaN
# 2         aaron        7            1.0                6.0         1.0
# 3         aback        0            NaN                NaN         NaN
# 4        abacus        0            NaN                NaN         NaN
# ...         ...      ...            ...                ...         ...
# 40444      zoom        0            NaN                NaN         NaN
# 40445   zooming        0            NaN                NaN         NaN
# 40446     zooms        0            NaN                NaN         NaN
# 40447  zucchini        0            NaN                NaN         NaN
# 40448    zurich        0            NaN                NaN         NaN
#
#        Ortho_N_KE(EXAM)  Ortho_N_KE(TEXTBOOK)  OLD_KE  OLD_KE(EXAM)  \
# 0                   1.0                   1.0    1.45          1.45
# 1                   NaN                   NaN     NaN           NaN
# 2                   1.0                   0.0    1.85          1.95
# 3                   NaN                   NaN     NaN           NaN
# 4                   NaN                   NaN     NaN           NaN
# ...                 ...                   ...     ...           ...
# 40444               NaN                   NaN     NaN           NaN
# 40445               NaN                   NaN     NaN           NaN
# 40446               NaN                   NaN     NaN           NaN
# 40447               NaN                   NaN     NaN           NaN
# 40448               NaN                   NaN     NaN           NaN
#
#        OLD_KE(TEXTBOOK)  ...  RFreq_HAL(130)  RFreq_HAL(160)  RFreq_SUBTLEX  \
# 0                  1.45  ...    81620.200000     66316.41250       20415.27
# 1                   NaN  ...        1.707692         1.38750          52.71
# 2                  2.00  ...       83.123077        67.53750          14.65
# 3                   NaN  ...        2.976923         2.41875           0.29
# 4                   NaN  ...        3.946154         3.20625           0.24
# ...                 ...  ...             ...             ...            ...
# 40444               NaN  ...       37.846154        30.75000           3.55
# 40445               NaN  ...        4.023077         3.26875           0.63
# 40446               NaN  ...        2.961538         2.40625           0.06
# 40447               NaN  ...        2.415385         1.96250           0.96
# 40448               NaN  ...       13.615385        11.06250           2.43
#
#         Zipf_KE  Zipf_KE(EXAM)  Zipf_KE(TEXTBOOK)   Zipf_KF  Zipf_HAL(130)  \
# 0      7.360356       7.341828           7.371453  7.340727       7.911473
# 1      3.117169            NaN                NaN  3.275558       3.234037
# 2      4.020259       3.652785           4.328203  3.877618       4.919437
# 3      3.117169            NaN                NaN  3.451649       3.474564
# 4      3.117169            NaN                NaN  2.974528       3.596695
# ...         ...            ...                ...       ...            ...
# 40444  3.117169            NaN                NaN  2.974528       4.577785
# 40445  3.117169            NaN                NaN  3.275558       3.605063
# 40446  3.117169            NaN                NaN  3.275558       3.472319
# 40447  3.117169            NaN                NaN  2.974528       3.384042
# 40448  3.117169            NaN                NaN  3.451649       4.133950
#
#        Zipf_HAL(160)  Zipf_SUBTLEX
# 0           7.821357      7.309323
# 1           3.143921      4.721422
# 2           4.829321      4.165786
# 3           3.384448      2.490180
# 4           3.506579      2.413686
# ...              ...           ...
# 40444       4.487669      3.551988
# 40445       3.514947      2.812019
# 40446       3.382203      1.900324
# 40447       3.293927      2.990420
# 40448       4.043835      3.388464
#
# [40449 rows x 57 columns]

# %%
# rank 정보를 rank method 사용햏서 tie 처리까지 한 번에. tie의  rank label은 avg 기준으로. 
ELP_LDT_data['KE_rank'] = ELP_LDT_data['Freq_KE'].rank(method='average', ascending=False)
ELP_LDT_data['SUBTLEX_rank'] = ELP_LDT_data['Freq_SUBTLEX'].rank(method='average', ascending=False)
ELP_LDT_data[['KE_rank', 'SUBTLEX_rank']]

# rank 정보를 % 정보로 변환
word_type_KE = (ELP_LDT_data['Freq_KE'] > 0).sum()
word_type_SUBTLEX = (ELP_LDT_data['Freq_SUBTLEX'] > 0).sum()
ELP_LDT_data['KE_rank'] = ELP_LDT_data['KE_rank'] / word_type_KE * 100.0
ELP_LDT_data['SUBTLEX_rank'] = ELP_LDT_data['SUBTLEX_rank'] / word_type_SUBTLEX * 100.0
ELP_LDT_data[['KE_rank', 'SUBTLEX_rank']].describe()
# Out:
#             KE_rank  SUBTLEX_rank
# count  40449.000000  40449.000000
# mean     123.677613     56.973436
# std       63.364271     32.859808
# min        0.006115      0.002817
# 25%       59.035039     28.434604
# 50%      173.677613     57.225556
# 75%      173.677613     84.378433
# max      173.677613    106.973436

# %%
# 분석에 사용할 빈도느 수는 SUBTLEX, KE이니 두 모퍼스 모두에서 최소 빈도가 1 이상인걸로 추출.
mask =  (ELP_LDT_data['Freq_KE'] > 0) & (ELP_LDT_data['Freq_SUBTLEX'] > 0)
ELP_LDT_data = ELP_LDT_data[mask]
ELP_LDT_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15995 entries, 0 to 40442
# Data columns (total 59 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Word                           15995 non-null  object
#  1   Freq_KE                        15995 non-null  int64
#  2   Freq_KE(EXAM)                  13727 non-null  float64
#  3   Freq_KE(TEXTBOOK)              11658 non-null  float64
#  4   Ortho_N_KE                     15995 non-null  float64
#  5   Ortho_N_KE(EXAM)               13727 non-null  float64
#  6   Ortho_N_KE(TEXTBOOK)           11658 non-null  float64
#  7   OLD_KE                         15995 non-null  float64
#  8   OLD_KE(EXAM)                   13727 non-null  float64
#  9   OLD_KE(TEXTBOOK)               11658 non-null  float64
#  10  Length                         15995 non-null  int64
#  11  Freq_KF                        15995 non-null  int64
#  12  Freq_HAL                       15995 non-null  int64
#  13  Freq_SUBTLEX                   15995 non-null  float64
#  14  SUBTLCD                        15995 non-null  float64
#  15  Ortho_N                        15995 non-null  int64
#  16  Phono_N                        15995 non-null  int64
#  17  OLD                            15995 non-null  float64
#  18  PLD                            15995 non-null  float64
#  19  Concreteness_Rating            10775 non-null  float64
#  20  Semantic_Neighborhood_Density  15994 non-null  float64
#  21  Semantic_Neighbors             15994 non-null  float64
#  22  Semantic_Diversity             14678 non-null  float64
#  23  Age_Of_Acquisition             14318 non-null  float64
#  24  Body_Object_Interaction        4603 non-null   float64
#  25  Emotional_Valence              7325 non-null   float64
#  26  Emotional_Arousal              7325 non-null   float64
#  27  Emotional_Dominance            7325 non-null   float64
#  28  Assoc_Freq_R1                  12924 non-null  float64
#  29  Assoc_Types_R1                 12924 non-null  float64
#  30  Assoc_Freq_R123                14429 non-null  float64
#  31  Assoc_Types_R123               14429 non-null  float64
#  32  POS                            15995 non-null  object
#  33  LDT_RT_MEAN                    15995 non-null  float64
#  34  LDT_RT_ZSCORE                  15995 non-null  float64
#  35  LDT_RT_SD                      15995 non-null  float64
#  36  LDT_RT_OBS                     15995 non-null  float64
#  37  LDT_ACC_MEAN                   15995 non-null  float64
#  38  NMG_RT_MEAN                    15995 non-null  float64
#  39  NMG_RT_ZSCORE                  15995 non-null  float64
#  40  NMG_RT_SD                      15995 non-null  float64
#  41  NMG_RT_OBS                     15995 non-null  int64
#  42  NMG_ACC_MEAN                   15995 non-null  float64
#  43  RFreq_KE                       15995 non-null  float64
#  44  RFreq_KE(EXAM)                 13727 non-null  float64
#  45  RFreq_KE(TEXTBOOK)             11658 non-null  float64
#  46  RFreq_KF                       15995 non-null  float64
#  47  RFreq_HAL(130)                 15995 non-null  float64
#  48  RFreq_HAL(160)                 15995 non-null  float64
#  49  RFreq_SUBTLEX                  15995 non-null  float64
#  50  Zipf_KE                        15995 non-null  float64
#  51  Zipf_KE(EXAM)                  13727 non-null  float64
#  52  Zipf_KE(TEXTBOOK)              11658 non-null  float64
#  53  Zipf_KF                        15995 non-null  float64
#  54  Zipf_HAL(130)                  15995 non-null  float64
#  55  Zipf_HAL(160)                  15995 non-null  float64
#  56  Zipf_SUBTLEX                   15995 non-null  float64
#  57  KE_rank                        15995 non-null  float64
#  58  SUBTLEX_rank                   15995 non-null  float64
# dtypes: float64(50), int64(7), object(2)
# memory usage: 7.3+ MB

# %%
# rank range가 100인 것 check.
ELP_LDT_data[['KE_rank', 'SUBTLEX_rank']].describe()
# Out:
#             KE_rank  SUBTLEX_rank
# count  15995.000000  15995.000000
# mean      49.601454     32.331827
# std       28.587622     24.551827
# min        0.006115      0.002817
# 25%       24.191280     11.943998
# 50%       52.042439     26.740190
# 75%       69.595793     48.811234
# max       87.996086     97.630919

# %%
ELP_LDT_data[['Zipf_KE', 'Zipf_SUBTLEX']].describe()
# Out:
#             Zipf_KE  Zipf_SUBTLEX
# count  15995.000000  15995.000000
# mean       4.008162      3.471007
# std        0.587020      0.850980
# min        3.418199      1.597149
# 25%        3.594290      2.885637
# 50%        3.816139      3.405841
# 75%        4.347618      3.991462
# max        7.700413      7.621137

# %%
ELP_LDT_data_path = os.path.join(corpora_dir, 'behavior-exp', 'ELP-LDT(251008-1200).xlsx')
#ELP_LDT_data.reset_index(drop=True).to_excel(ELP_LDT_data_path, index=False)

# %%
ELP_LDT_data = pd.read_excel(ELP_LDT_data_path)
ELP_LDT_data
#ELP_LDT_data.reset_index(drop=True)
# Out:
#              Word  Freq_KE  Freq_KE(EXAM)  Freq_KE(TEXTBOOK)  Ortho_N_KE  \
# 0               a    17505         9773.0             7732.0           1
# 1           aaron        7            1.0                6.0           1
# 2         abandon        7            5.0                2.0           0
# 3       abandoned       12            5.0                7.0           0
# 4      abandoning        3            3.0                NaN           0
# ...           ...      ...            ...                ...         ...
# 15990     zombies        3            NaN                3.0           0
# 15991        zone       19            6.0               13.0           7
# 15992       zones       17            8.0                9.0           4
# 15993         zoo       31           21.0               10.0           4
# 15994   zoologist        2            2.0                NaN           0
#
#        Ortho_N_KE(EXAM)  Ortho_N_KE(TEXTBOOK)  OLD_KE  OLD_KE(EXAM)  \
# 0                   1.0                   1.0    1.45          1.45
# 1                   1.0                   0.0    1.85          1.95
# 2                   0.0                   0.0    2.90          3.05
# 3                   0.0                   0.0    3.50          3.50
# 4                   0.0                   NaN    3.60          3.60
# ...                 ...                   ...     ...           ...
# 15990               NaN                   0.0    2.60           NaN
# 15991               7.0                   7.0    1.40          1.40
# 15992               4.0                   4.0    1.60          1.60
# 15993               1.0                   4.0    1.70          1.85
# 15994               0.0                   NaN    3.90          3.90
#
#        OLD_KE(TEXTBOOK)  ...  RFreq_SUBTLEX   Zipf_KE  Zipf_KE(EXAM)  \
# 0                  1.45  ...       20415.27  7.360356       7.341828
# 1                  2.00  ...          14.65  4.020259       3.652785
# 2                  3.00  ...           8.10  4.020259       4.129906
# 3                  3.60  ...          13.29  4.231112       4.129906
# 4                   NaN  ...           1.69  3.719229       3.953815
# ...                 ...  ...            ...       ...            ...
# 15990              2.65  ...           2.25  3.719229            NaN
# 15991              1.40  ...          20.12  4.418199       4.196853
# 15992              1.60  ...           1.76  4.372441       4.305998
# 15993              1.70  ...          13.65  4.622319       4.694178
# 15994               NaN  ...           0.24  3.594290       3.828876
#
#        Zipf_KE(TEXTBOOK)   Zipf_KF  Zipf_HAL(130)  Zipf_HAL(160)  \
# 0               7.371453  7.340727       7.911473       7.821357
# 1               4.328203  3.877618       4.919437       4.829321
# 2               3.960226  4.229800       4.461151       4.371035
# 3               4.386195  4.389501       4.598466       4.508350
# 4                    NaN  3.877618       3.888330       3.798214
# ...                  ...       ...            ...            ...
# 15990           4.085165  3.275558       4.298864       4.208748
# 15991           4.629233  4.053709       5.123803       5.033687
# 15992           4.483105  3.576588       4.415803       4.325688
# 15993           4.524498  3.974528       4.521014       4.430899
# 15994                NaN  3.451649       3.365739       3.275623
#
#        Zipf_SUBTLEX    KE_rank  SUBTLEX_rank
# 0          7.309323   0.018345      0.014085
# 1          4.165786  39.427016      8.972084
# 2          3.908903  39.427016     13.494746
# 3          4.123533  29.049716      9.577735
# 4          3.232264  59.035039     33.130511
# ...             ...        ...           ...
# 15990      3.355319  59.035039     28.434604
# 15991      4.303419  21.384455      7.129778
# 15992      3.249692  23.188406     32.369926
# 15993      4.135124  14.936097      9.419984
# 15994      2.413686  69.595793     71.247077
#
# [15995 rows x 59 columns]

# %%
ELP_LDT_data[['Freq_KE', 'Freq_SUBTLEX']].describe()
# Out:
#             Freq_KE  Freq_SUBTLEX
# count  15995.000000  1.599500e+04
# mean      44.223695  2.782269e+03
# std      501.970088  3.546843e+04
# min        1.000000  1.020000e+00
# 25%        2.000000  3.825000e+01
# 50%        4.000000  1.290300e+02
# 75%       16.000000  4.998000e+02
# max    38303.000000  2.134713e+06

# %%
mask = ELP_LDT_data['KE_rank'] <= 100
ELP_LDT_data[['Zipf_SUBTLEX', 'Zipf_KE']][mask].corr(method='spearman')
# Out:
#               Zipf_SUBTLEX   Zipf_KE
# Zipf_SUBTLEX      1.000000  0.678456
# Zipf_KE           0.678456  1.000000

# %%
mask = KE_E_final_df['Freq_KE'] >= 5
KE_E_final_df[['Freq_SUBTLEX', 'Freq_KE']][mask].corr(method='spearman')
# Out:
#               Freq_SUBTLEX   Freq_KE
# Freq_SUBTLEX      1.000000  0.640742
# Freq_KE           0.640742  1.000000

# %%
mask = ELP_LDT_data['KE_rank'] <= 77
ELP_LDT_data[mask][['SUBTLEX_rank', 'KE_rank']].corr(method='pearson')
# Out:
#               SUBTLEX_rank   KE_rank
# SUBTLEX_rank      1.000000  0.601728
# KE_rank           0.601728  1.000000

# %%
def plot_word_group_ranks_by_corpus(df, word_col, rank_columns, word_groups, group_names=None, figsize=(15, 8)):
    """
    HF/LF 그룹의 단어들을 입력받아 코퍼스별 rank 위치를 boxplot으로 시각화
    """
    
    if group_names is None:
        group_names = [f'Group {i+1}' for i in range(len(word_groups))]
    
    # seaborn 스타일 설정
    sns.set_style("whitegrid")
    plt.rcParams['font.family'] = 'AppleGothic'
    
    # 데이터 준비
    plot_data = []
    
    for corpus_col in rank_columns:
        for group_words, group_name in zip(word_groups, group_names):
            # 해당 그룹의 단어들이 데이터프레임에 있는지 확인
            available_words = [word for word in group_words if word in df[word_col].values]
            
            if available_words:
                # 해당 단어들의 rank 값 추출
                mask = df[word_col].isin(available_words)
                ranks = df[mask][corpus_col].values
                
                # 각 rank 값에 대해 데이터 포인트 추가
                for rank in ranks:
                    plot_data.append({
                        'Corpus': corpus_col,
                        'Group': group_name,
                        'Rank': rank
                    })
            else:
                print(f"Warning: {group_name} 그룹의 단어들이 데이터에 없습니다.")
    
    # DataFrame으로 변환
    plot_df = pd.DataFrame(plot_data)
    
    if plot_df.empty:
        print("그래프를 그릴 데이터가 없습니다.")
        return None
    
    # 그래프 생성
    fig, ax = plt.subplots(1, 1, figsize=figsize)
    
    # Boxplot 그리기
    sns.boxplot(data=plot_df, x='Corpus', y='Rank', hue='Group', ax=ax)
    
    # 개별 데이터 포인트 표시 (strip plot) - legend=False로 중복 legend 방지
    sns.stripplot(data=plot_df, x='Corpus', y='Rank', hue='Group', 
                  dodge=True, size=6, alpha=0.6, legend=False, ax=ax)
    
    # y축 반전 - 수치가 작은 값이 위로 가도록
    ax.invert_yaxis()
    
    # 축 레이블 및 제목 설정
    ax.set_xlabel('Corpus', fontsize=14, fontweight='bold')
    ax.set_ylabel('Relative Rank Position (%)', fontsize=14, fontweight='bold')
    ax.set_title('Word Group Rank Positions Across Corpora', fontsize=16, fontweight='bold')
    
    # y축 범위 설정 (0-100%)
    ax.set_ylim(100, 0)
    
    # 그리드 설정
    ax.grid(True, alpha=0.3)
    
    # 축 스타일 개선
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_linewidth(0.5)
    ax.spines['bottom'].set_linewidth(0.5)
    
    # 레이아웃 조정
    plt.legend(loc='lower right', bbox_to_anchor=(1, 0))
    plt.tight_layout()
    plt.show()
    
    # 통계 정보 출력
    print("\n=== 그룹별 Rank 통계 ===")
    for corpus in rank_columns:
        print(f"\n{corpus}:")
        for group in group_names:
            group_data = plot_df[(plot_df['Corpus'] == corpus) & (plot_df['Group'] == group)]['Rank']
            if len(group_data) > 0:
                print(f"  {group}: 평균={group_data.mean():.2f}%, 중앙값={group_data.median():.2f}%, 표준편차={group_data.std():.2f}%")
    
    return fig, plot_df

# %%
ELP_LDT_data[['Zipf_SUBTLEX', 'Zipf_KE']].describe()
# Out:
#        Zipf_SUBTLEX       Zipf_KE
# count  15995.000000  15995.000000
# mean       3.471007      4.008162
# std        0.850980      0.587020
# min        1.597149      3.418199
# 25%        2.885637      3.594290
# 50%        3.405841      3.816139
# 75%        3.991462      4.347618
# max        7.621137      7.700413

# %%
#KE_Freq_unique_values = 
ELP_LDT_data['Freq_KE'].value_counts().sort_index()
# Out:
# Freq_KE
# 1        3750
# 2        2038
# 3        1335
# 4         907
# 5         745
#          ...
# 16818       1
# 17171       1
# 17505       1
# 21665       1
# 38303       1
# Name: count, Length: 496, dtype: int64

# %%
KE_E_final_df['Freq_KE'].value_counts().sort_index()
# Out:
# Freq_KE
# 0        24127
# 1         3927
# 2         2091
# 3         1363
# 4          924
#          ...
# 16818        1
# 17171        1
# 17505        1
# 21665        1
# 38303        1
# Name: count, Length: 497, dtype: int64

# %%
KE_E_final_df['Freq_SUBTLEX'].value_counts().sort_index()
# Out:
# Freq_SUBTLEX
# 0.00          4966
# 1.02          1684
# 2.04          1341
# 3.06          1145
# 4.08           943
#               ...
# 1041178.77       1
# 1156569.84       1
# 1501908.18       1
# 2038529.16       1
# 2134713.12       1
# Name: count, Length: 2990, dtype: int64

# %%
mask_diff = ELP_LDT_data['KE_rank'] - ELP_LDT_data['SUBTLEX_rank'] > 15 # KE에서 더 저빈도
mask_stable = abs(ELP_LDT_data['KE_rank'] - ELP_LDT_data['SUBTLEX_rank']) < 1 # 두 코퍼스 모두에서 stable한 빈도 단어들

# subltex 기준 빈도수 구간 분할
mask1 = (2 <= ELP_LDT_data['Zipf_SUBTLEX']) & (ELP_LDT_data['Zipf_SUBTLEX'] < 3)
mask2 = (3 <= ELP_LDT_data['Zipf_SUBTLEX']) & (ELP_LDT_data['Zipf_SUBTLEX'] < 4)
mask3 = (4 <= ELP_LDT_data['Zipf_SUBTLEX']) & (ELP_LDT_data['Zipf_SUBTLEX'] < 5)
mask4 = (5 <= ELP_LDT_data['Zipf_SUBTLEX']) & (ELP_LDT_data['Zipf_SUBTLEX'] < 6)
mask5 = (6 <= ELP_LDT_data['Zipf_SUBTLEX']) & (ELP_LDT_data['Zipf_SUBTLEX'] < 7)

print(f"Word count: {len(ELP_LDT_data[mask_diff & mask1])} in Zipf-SUBTLEX range [2,3)")
print(f"Word count: {len(ELP_LDT_data[mask_diff & mask2])} in Zipf-SUBTLEX range [3,4)")
print(f"Word count: {len(ELP_LDT_data[mask_diff & mask3])} in Zipf-SUBTLEX range [4,5)")
print(f"Word count: {len(ELP_LDT_data[mask_diff & mask4])} in Zipf-SUBTLEX range [5,6)")
print(f"Word count: {len(ELP_LDT_data[mask_diff & mask5])} in Zipf-SUBTLEX range [6,7)")
# Out:
# Word count: 272 in Zipf-SUBTLEX range [2,3)
# Word count: 2287 in Zipf-SUBTLEX range [3,4)
# Word count: 970 in Zipf-SUBTLEX range [4,5)
# Word count: 44 in Zipf-SUBTLEX range [5,6)
# Word count: 0 in Zipf-SUBTLEX range [6,7)

# %%
mask_diff = ELP_LDT_data['KE_rank'] - ELP_LDT_data['SUBTLEX_rank'] > 15 # KE에서 더 저빈도
mask_stable = abs(ELP_LDT_data['KE_rank'] - ELP_LDT_data['SUBTLEX_rank']) < 0.1 # 두 코퍼스 모두에서 stable한 빈도 단어들

freq_range = [(5, 20), (20, 35), (35, 50), (50, 65), (65, 80), (80, 95)]
# subltex 기준 빈도수 구간 분할
masks = []
for low, high in freq_range:
    mask = (low <= ELP_LDT_data['SUBTLEX_rank']) & (ELP_LDT_data['SUBTLEX_rank'] < high) & (low <= ELP_LDT_data['KE_rank']) & (ELP_LDT_data['KE_rank'] < high)
    masks.append((mask, low, high))

for mask, mask_min, mask_max in masks:
    print(f"Word count: {len(ELP_LDT_data[mask & mask_stable])} in Zipf-SUBTLEX range [{mask_min},{mask_max})")
# Out:
# Word count: 25 in Zipf-SUBTLEX range [5,20)
# Word count: 10 in Zipf-SUBTLEX range [20,35)
# Word count: 6 in Zipf-SUBTLEX range [35,50)
# Word count: 3 in Zipf-SUBTLEX range [50,65)
# Word count: 2 in Zipf-SUBTLEX range [65,80)
# Word count: 0 in Zipf-SUBTLEX range [80,95)

# %%
mask_diff = ELP_LDT_data['KE_rank'] - ELP_LDT_data['SUBTLEX_rank'] > 15 # KE에서 더 저빈도
mask_stable = abs(ELP_LDT_data['KE_rank'] - ELP_LDT_data['SUBTLEX_rank']) < 0.1 # 두 코퍼스 모두에서 stable한 빈도 단어들
mask_pos = ELP_LDT_data['POS'].str.contains('NN')

# 8개의 구간에서 추출. 120개 단어이니, 15개씩
freq_range = [(1.5, 2.0), (2.0, 2.5), (2.5, 3.0), (3.0, 3.5), (3.5, 4.0), (4.0, 4.5), (4.5, 5.0), (5.0, 5.5), (5.5, 6.0), (6.0, 6.5)]
# subltex 기준 빈도수 구간 분할
masks_sub = []
masks_ke = []
for low, high in freq_range:
    mask = (low <= ELP_LDT_data['Zipf_SUBTLEX']) & (ELP_LDT_data['Zipf_SUBTLEX'] < high)
    masks_sub.append((mask, low, high))
    mask = (low <= ELP_LDT_data['Zipf_KE']) & (ELP_LDT_data['Zipf_KE'] < high)
    masks_ke.append((mask, low, high))

for mask, mask_min, mask_max in masks_sub:
    print(f"Word count: {len(ELP_LDT_data[mask])} in Zipf-SUBTLEX range [{mask_min},{mask_max})")

for mask, mask_min, mask_max in masks_ke:
    print(f"Word count: {len(ELP_LDT_data[mask])} in Zipf-KE range [{mask_min},{mask_max})")
# Out:
# Word count: 525 in Zipf-SUBTLEX range [1.5,2.0)
# Word count: 1361 in Zipf-SUBTLEX range [2.0,2.5)
# Word count: 2942 in Zipf-SUBTLEX range [2.5,3.0)
# Word count: 3865 in Zipf-SUBTLEX range [3.0,3.5)
# Word count: 3352 in Zipf-SUBTLEX range [3.5,4.0)
# Word count: 2210 in Zipf-SUBTLEX range [4.0,4.5)
# Word count: 1025 in Zipf-SUBTLEX range [4.5,5.0)
# Word count: 406 in Zipf-SUBTLEX range [5.0,5.5)
# Word count: 182 in Zipf-SUBTLEX range [5.5,6.0)
# Word count: 75 in Zipf-SUBTLEX range [6.0,6.5)
# Word count: 0 in Zipf-KE range [1.5,2.0)
# Word count: 0 in Zipf-KE range [2.0,2.5)
# Word count: 0 in Zipf-KE range [2.5,3.0)
# Word count: 3750 in Zipf-KE range [3.0,3.5)
# Word count: 5616 in Zipf-KE range [3.5,4.0)
# Word count: 3636 in Zipf-KE range [4.0,4.5)
# Word count: 1848 in Zipf-KE range [4.5,5.0)
# Word count: 824 in Zipf-KE range [5.0,5.5)
# Word count: 199 in Zipf-KE range [5.5,6.0)
# Word count: 83 in Zipf-KE range [6.0,6.5)

# %%
low = 6.5
high = 7.0
mask = (low <= ELP_LDT_data['Zipf_SUBTLEX']) & (ELP_LDT_data['Zipf_SUBTLEX'] < high)
ELP_LDT_data[mask & mask_pos][['Word', 'Freq_SUBTLEX', 'Freq_KE', 'Zipf_SUBTLEX', 'Zipf_KE', 'POS']][:50]
# Out:
#         Word  Freq_SUBTLEX  Freq_KE  Zipf_SUBTLEX   Zipf_KE             POS
# 1952     can     267619.95     4016      6.719318  6.721071           VB|NN
# 4248      do     312915.09     2688      6.787226  6.546760           VB|NN
# 4291     don     321084.78     1045      6.798419  6.136700           VB|NN
# 6196      go     193445.04      951      6.578358  6.095806           VB|NN
# 6567    have     314231.91     4078      6.789049  6.727722           VB|NN
# 6673    here     230787.75      681      6.655012  5.950953           RB|NN
# 7843    just     242206.14      951      6.675985  6.095806        RB|JJ|NN
# 7942    know     291780.18     1000      6.756855  6.117603           VB|NN
# 8219    like     203946.96     1773      6.601317  6.366122  minor|VB|NN|JJ
# 9497     now     163333.11     1065      6.504875  6.144926        RB|JJ|NN
# 9639      oh     167780.82      598      6.516543  5.894596        minor|NN
# 12017  right     204427.89      922      6.602340  6.082370     NN|JJ|RB|VB
# 14394   this     406915.23     4186      6.901303  6.739072        minor|NN

# %%
ELP_LDT_data[masks[1][0] & mask_stable][['Word', 'Zipf_KE', 'Zipf_SUBTLEX', 'KE_rank', 'SUBTLEX_rank']]#[['KE_rank', 'SUBTLEX_rank']]#.corr(method='spearman')
# Out:
#              Word   Zipf_KE  Zipf_SUBTLEX    KE_rank  SUBTLEX_rank
# 3306     survived  4.439388      4.111960  20.743982     20.675211
# 3513         link  4.418199      4.077085  21.900594     21.969365
# 3617      shadows  4.395922      4.058158  22.532041     22.619569
# 3630     promises  4.395922      4.055877  22.775867     22.700844
# 3648  shakespeare  4.395922      4.053583  22.732104     22.813379
# 3788       wizard  4.372441      4.026701  23.719912     23.688653
# 3904     chickens  4.347618      4.008802  24.407627     24.413879
# 4242      planted  4.293260      3.951657  26.439512     26.527040
# 4315          tin  4.293260      3.937367  27.008440     26.983432
# 5066    promising  4.196350      3.819544  31.734917     31.678650

# %%
# SUBTLEX 기준 95%는 7번 이상 등장.
mask = ELP_LDT_data['KE_rank'] > 77
ELP_LDT_data[mask]['Freq_KE'].describe()
# Out:
# count    3679.0
# mean        1.0
# std         0.0
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         1.0
# max         1.0
# Name: Freq_KE, dtype: float64

# %%
i=1
while True:
    percentage = ELP_LDT_data[mask].shape[0] / ELP_LDT_data.shape[0]
    if percentage < 0.01:
        break
    mask = ELP_LDT_data['Freq_KE'] == i
    print(f"{i}-freq word percentage:{percentage}")
    i += 1
# Out:
# 1-freq word percentage:0.40137542982181934
# 2-freq word percentage:0.2344482650828384
# 3-freq word percentage:0.12741481713035324
# 4-freq word percentage:0.08346358236949046
# 5-freq word percentage:0.05670522038136918
# 6-freq word percentage:0.04657705532979056
# 7-freq word percentage:0.036949046577055326
# 8-freq word percentage:0.02975929978118162
# 9-freq word percentage:0.025695529853079088
# 10-freq word percentage:0.021631759924976554
# 11-freq word percentage:0.019381056580181306
# 12-freq word percentage:0.016567677399187245
# 13-freq word percentage:0.013504220068771491
# 14-freq word percentage:0.013816817755548608
# 15-freq word percentage:0.012566427008440137
# 16-freq word percentage:0.011316036261331666
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_70518/3594634040.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   percentage = ELP_LDT_data[mask].shape[0] / ELP_LDT_data.shape[0]

# %%
ELP_LDT_data[mask_stable & mask3].sort_values('Zipf_SUBTLEX')
# Out:
#               Word  Freq_KE  Freq_KE(EXAM)  Freq_KE(TEXTBOOK)  Ortho_N_KE  \
# 715       watching      110           61.0               49.0         3.0
# 721         finish      114           65.0               49.0         0.0
# 731         choice      126           91.0               35.0         0.0
# 733       birthday      104           85.0               19.0         0.0
# 738          smart      115           23.0               92.0         1.0
# ...            ...      ...            ...                ...         ...
# 3792          fund       17           12.0                5.0         2.0
# 3838     believing       16           12.0                4.0         1.0
# 3876  specifically       17           12.0                5.0         0.0
# 3904      chickens       16            6.0               10.0         1.0
# 3913         brick       15            3.0               12.0         2.0
#
#       Ortho_N_KE(EXAM)  Ortho_N_KE(TEXTBOOK)  OLD_KE  OLD_KE(EXAM)  \
# 715                3.0                   2.0    2.15          2.20
# 721                0.0                   0.0    2.00          2.20
# 731                0.0                   0.0    2.45          2.45
# 733                0.0                   0.0    3.70          3.75
# 738                1.0                   1.0    1.80          1.80
# ...                ...                   ...     ...           ...
# 3792               2.0                   2.0    1.65          1.65
# 3838               1.0                   1.0    2.70          2.95
# 3876               0.0                   0.0    4.10          4.10
# 3904               1.0                   0.0    2.50          2.75
# 3913               1.0                   2.0    1.70          1.75
#
#       OLD_KE(TEXTBOOK)  ...  RFreq_SUBTLEX   Zipf_KE  Zipf_KE(EXAM)  \
# 715               2.35  ...          99.63  5.162492       5.144147
# 721               2.20  ...          98.92  5.177867       5.171299
# 731               2.50  ...          97.55  5.220972       5.315543
# 733               3.75  ...          97.22  5.138358       5.286254
# 738               1.85  ...          96.25  5.181627       4.731966
# ...                ...  ...            ...       ...            ...
# 3792              1.65  ...          10.61  4.372441       4.465699
# 3838              2.85  ...          10.43  4.347618       4.465699
# 3876              4.30  ...          10.27  4.372441       4.465699
# 3904              2.70  ...          10.20  4.347618       4.196853
# 3913              1.70  ...          10.18  4.321289       3.953815
#
#       Zipf_KE(TEXTBOOK)   Zipf_KF  Zipf_HAL(130)  Zipf_HAL(160)  Zipf_SUBTLEX  \
# 715            5.182075  4.861019       5.361984       5.271868      4.997843
# 721            5.182075  4.576588       5.150526       5.060410      4.994738
# 731            5.039408  5.031433       5.702192       5.612076      4.988682
# 733            4.784135  4.253281       4.818104       4.727988      4.987211
# 738            5.451588  4.316951       5.135737       5.045621      4.982857
# ...                 ...       ...            ...            ...           ...
# 3792           4.261256  4.773868       5.134588       5.044472      4.025885
# 3838           4.182075  4.150619       4.730768       4.640652      4.018468
# 3876           4.261256  4.565592       5.399708       5.309592      4.011767
# 3904           4.524498  4.120656       4.124530       4.034415      4.008802
# 3913           4.597049  4.253281       4.484522       4.394407      4.007951
#
#         KE_rank  SUBTLEX_rank
# 715    4.757737      4.476399
# 721    4.670209      4.513911
# 731    4.201313      4.576430
# 733    5.045327      4.588934
# 738    4.632698      4.620194
# ...         ...           ...
# 3792  23.388559     23.713661
# 3838  24.820256     24.001250
# 3876  23.844952     24.238825
# 3904  24.407627     24.413879
# 3913  25.132854     24.470147
#
# [279 rows x 59 columns]

# %%
word_groups = [ELP_LDT_data['Word']]
group_names = ['ELP LDT Words']
rank_columns = ['KE_rank', 'SUBTLEX_rank']

print(f"ELP_LDT_words: {len(ELP_LDT_data)}")

# 함수 실행
fig, plot_df = plot_word_group_ranks_by_corpus(
    df=ELP_LDT_data, 
    word_col='Word', 
    rank_columns=rank_columns,
    word_groups=word_groups, 
    group_names=group_names, 
    figsize=(12, 8)
)
# Out:
# ELP_LDT_words: 15995
# === 그룹별 Rank 통계 ===
#
# KE_rank:
#   ELP LDT Words: 평균=49.60%, 중앙값=52.04%, 표준편차=28.59%
#
# SUBTLEX_rank:
#   ELP LDT Words: 평균=32.33%, 중앙값=26.74%, 표준편차=24.55%

# %%
word_groups = []
group_names = []

freq_range = [(1.5, 2.0), (2.0, 2.5), (2.5, 3.0), (3.0, 3.5), (3.5, 4.0), (4.0, 4.5), (4.5, 5.0), (5.0, 5.5), (5.5, 6.0), (6.0, 6.5)]

for freq_min, freq_max in freq_range:
    mask = (freq_min <= ELP_LDT_data['Zipf_SUBTLEX']) & (ELP_LDT_data['Zipf_SUBTLEX'] < freq_max)
    print(f"{freq_min} <= Zipf_SUBTLEX < {freq_max} Words: {len(ELP_LDT_data[mask])}")
    word_groups.append(ELP_LDT_data[mask & mask_pos]['Word'])
    group_names.append(f'{freq_min} <= SUBTLEX_Zipf < {freq_max}')

rank_columns = ['KE_rank', 'SUBTLEX_rank']

# 함수 실행
fig, plot_df = plot_word_group_ranks_by_corpus(
    df=ELP_LDT_data, 
    word_col='Word', 
    rank_columns=rank_columns,
    word_groups=word_groups, 
    group_names=group_names, 
    figsize=(12, 8)
)
# Out:
# 1.5 <= Zipf_SUBTLEX < 2.0 Words: 525
# 2.0 <= Zipf_SUBTLEX < 2.5 Words: 1361
# 2.5 <= Zipf_SUBTLEX < 3.0 Words: 2942
# 3.0 <= Zipf_SUBTLEX < 3.5 Words: 3865
# 3.5 <= Zipf_SUBTLEX < 4.0 Words: 3352
# 4.0 <= Zipf_SUBTLEX < 4.5 Words: 2210
# 4.5 <= Zipf_SUBTLEX < 5.0 Words: 1025
# 5.0 <= Zipf_SUBTLEX < 5.5 Words: 406
# 5.5 <= Zipf_SUBTLEX < 6.0 Words: 182
# 6.0 <= Zipf_SUBTLEX < 6.5 Words: 75
# === 그룹별 Rank 통계 ===
#
# KE_rank:
#   1.5 <= SUBTLEX_Zipf < 2.0: 평균=77.31%, 중앙값=88.00%, 표준편차=15.63%
#   2.0 <= SUBTLEX_Zipf < 2.5: 평균=73.62%, 중앙값=88.00%, 표준편차=17.33%
#   2.5 <= SUBTLEX_Zipf < 3.0: 평균=67.03%, 중앙값=69.60%, 표준편차=20.67%
#   3.0 <= SUBTLEX_Zipf < 3.5: 평균=56.05%, 중앙값=59.04%, 표준편차=23.41%
#   3.5 <= SUBTLEX_Zipf < 4.0: 평균=44.94%, 중앙값=42.75%, 표준편차=24.20%
#   4.0 <= SUBTLEX_Zipf < 4.5: 평균=29.84%, 중앙값=23.19%, 표준편차=21.87%
#   4.5 <= SUBTLEX_Zipf < 5.0: 평균=16.21%, 중앙값=10.71%, 표준편차=16.03%
#   5.0 <= SUBTLEX_Zipf < 5.5: 평균=8.10%, 중앙값=4.52%, 표준편차=10.55%
#   5.5 <= SUBTLEX_Zipf < 6.0: 평균=3.67%, 중앙값=1.79%, 표준편차=6.50%
#   6.0 <= SUBTLEX_Zipf < 6.5: 평균=0.99%, 중앙값=0.85%, 표준편차=0.73%
#
# SUBTLEX_rank:
#   1.5 <= SUBTLEX_Zipf < 2.0: 평균=92.12%, 중앙값=89.88%, 표준편차=4.02%
#   2.0 <= SUBTLEX_Zipf < 2.5: 평균=74.98%, 중앙값=74.37%, 표준편차=5.36%
#   2.5 <= SUBTLEX_Zipf < 3.0: 평균=53.77%, 중앙값=53.49%, 표준편차=6.59%
#   3.0 <= SUBTLEX_Zipf < 3.5: 평균=32.49%, 중앙값=31.88%, 표준편차=5.53%
#   3.5 <= SUBTLEX_Zipf < 4.0: 평균=17.39%, 중앙값=17.22%, 표준편차=3.47%
#   4.0 <= SUBTLEX_Zipf < 4.5: 평균=8.32%, 중앙값=8.28%, 표준편차=1.92%
#   4.5 <= SUBTLEX_Zipf < 5.0: 평균=3.53%, 중앙값=3.51%, 표준편차=0.87%
#   5.0 <= SUBTLEX_Zipf < 5.5: 평균=1.47%, 중앙값=1.48%, 표준편차=0.33%
#   5.5 <= SUBTLEX_Zipf < 6.0: 평균=0.62%, 중앙값=0.62%, 표준편차=0.15%
#   6.0 <= SUBTLEX_Zipf < 6.5: 평균=0.26%, 중앙값=0.27%, 표준편차=0.07%

# %%
word_groups = []
group_names = []

dfs = []

zipf_range = [(2.0, 2.5), (2.5, 3.0), (3.0, 3.5), (3.5, 4.0), (4.0, 4.5), (4.5, 5.0), (5.0, 5.5), (5.5, 6.0)]

for zipf_min, zipf_max in zipf_range:
    # zipf-scale로 구획화.
    mask = (zipf_min <= ELP_LDT_data['Zipf_SUBTLEX']) & (ELP_LDT_data['Zipf_SUBTLEX'] < zipf_max)
    # 위 단어들에 해당하는 KE 그래프에서 IQR 내 단어들만 survive.
    rank_Q1, rank_Q3 = ELP_LDT_data[mask]['KE_rank'].quantile(0.25), ELP_LDT_data[mask]['KE_rank'].quantile(0.75)
    mask2 = (rank_Q1 <= ELP_LDT_data['KE_rank']) & (ELP_LDT_data['KE_rank'] <= rank_Q3)
    # pos tagging까지 같이.
    print(f"{zipf_min} <= Zipf_SUBTLEX < {zipf_max} Words: {len(ELP_LDT_data[mask][mask2][mask_pos])}")
    # 순서대로 적용해야 IQR이 잘 들어가니, 반드시 아래의 식으로 적용.
    dfs.append(ELP_LDT_data[mask][mask2][mask_pos])
    word_groups.append(ELP_LDT_data[mask & mask2 & mask_pos]['Word'])
    group_names.append(f'{zipf_min} <= SUBTLEX_Zipf < {zipf_max}')

rank_columns = ['KE_rank', 'SUBTLEX_rank']

# 함수 실행
fig, plot_df = plot_word_group_ranks_by_corpus(
    df=ELP_LDT_data, 
    word_col='Word', 
    rank_columns=rank_columns,
    word_groups=word_groups, 
    group_names=group_names, 
    figsize=(12, 8)
)
# Out:
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(f"{zipf_min} <= Zipf_SUBTLEX < {zipf_max} Words: {len(ELP_LDT_data[mask][mask2][mask_pos])}")
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(f"{zipf_min} <= Zipf_SUBTLEX < {zipf_max} Words: {len(ELP_LDT_data[mask][mask2][mask_pos])}")
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfs.append(ELP_LDT_data[mask][mask2][mask_pos])
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfs.append(ELP_LDT_data[mask][mask2][mask_pos])
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(f"{zipf_min} <= Zipf_SUBTLEX < {zipf_max} Words: {len(ELP_LDT_data[mask][mask2][mask_pos])}")
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(f"{zipf_min} <= Zipf_SUBTLEX < {zipf_max} Words: {len(ELP_LDT_data[mask][mask2][mask_pos])}")
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfs.append(ELP_LDT_data[mask][mask2][mask_pos])
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfs.append(ELP_LDT_data[mask][mask2][mask_pos])
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(f"{zipf_min} <= Zipf_SUBTLEX < {zipf_max} Words: {len(ELP_LDT_data[mask][mask2][mask_pos])}")
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(f"{zipf_min} <= Zipf_SUBTLEX < {zipf_max} Words: {len(ELP_LDT_data[mask][mask2][mask_pos])}")
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfs.append(ELP_LDT_data[mask][mask2][mask_pos])
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfs.append(ELP_LDT_data[mask][mask2][mask_pos])
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(f"{zipf_min} <= Zipf_SUBTLEX < {zipf_max} Words: {len(ELP_LDT_data[mask][mask2][mask_pos])}")
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(f"{zipf_min} <= Zipf_SUBTLEX < {zipf_max} Words: {len(ELP_LDT_data[mask][mask2][mask_pos])}")
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfs.append(ELP_LDT_data[mask][mask2][mask_pos])
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfs.append(ELP_LDT_data[mask][mask2][mask_pos])
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(f"{zipf_min} <= Zipf_SUBTLEX < {zipf_max} Words: {len(ELP_LDT_data[mask][mask2][mask_pos])}")
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(f"{zipf_min} <= Zipf_SUBTLEX < {zipf_max} Words: {len(ELP_LDT_data[mask][mask2][mask_pos])}")
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfs.append(ELP_LDT_data[mask][mask2][mask_pos])
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfs.append(ELP_LDT_data[mask][mask2][mask_pos])
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(f"{zipf_min} <= Zipf_SUBTLEX < {zipf_max} Words: {len(ELP_LDT_data[mask][mask2][mask_pos])}")
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(f"{zipf_min} <= Zipf_SUBTLEX < {zipf_max} Words: {len(ELP_LDT_data[mask][mask2][mask_pos])}")
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfs.append(ELP_LDT_data[mask][mask2][mask_pos])
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfs.append(ELP_LDT_data[mask][mask2][mask_pos])
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(f"{zipf_min} <= Zipf_SUBTLEX < {zipf_max} Words: {len(ELP_LDT_data[mask][mask2][mask_pos])}")
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(f"{zipf_min} <= Zipf_SUBTLEX < {zipf_max} Words: {len(ELP_LDT_data[mask][mask2][mask_pos])}")
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfs.append(ELP_LDT_data[mask][mask2][mask_pos])
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfs.append(ELP_LDT_data[mask][mask2][mask_pos])
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(f"{zipf_min} <= Zipf_SUBTLEX < {zipf_max} Words: {len(ELP_LDT_data[mask][mask2][mask_pos])}")
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(f"{zipf_min} <= Zipf_SUBTLEX < {zipf_max} Words: {len(ELP_LDT_data[mask][mask2][mask_pos])}")
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfs.append(ELP_LDT_data[mask][mask2][mask_pos])
# /var/folders/3t/7cyq0j713bn7qcyfypl8dx3w0000gn/T/ipykernel_10780/1682813898.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfs.append(ELP_LDT_data[mask][mask2][mask_pos])
# 2.0 <= Zipf_SUBTLEX < 2.5 Words: 505
# 2.5 <= Zipf_SUBTLEX < 3.0 Words: 1237
# 3.0 <= Zipf_SUBTLEX < 3.5 Words: 1291
# 3.5 <= Zipf_SUBTLEX < 4.0 Words: 1269
# 4.0 <= Zipf_SUBTLEX < 4.5 Words: 872
# 4.5 <= Zipf_SUBTLEX < 5.0 Words: 400
# 5.0 <= Zipf_SUBTLEX < 5.5 Words: 151
# 5.5 <= Zipf_SUBTLEX < 6.0 Words: 66
# === 그룹별 Rank 통계 ===
#
# KE_rank:
#   2.0 <= SUBTLEX_Zipf < 2.5: 평균=82.35%, 중앙값=88.00%, 표준편차=8.50%
#   2.5 <= SUBTLEX_Zipf < 3.0: 평균=75.84%, 중앙값=88.00%, 표준편차=13.28%
#   3.0 <= SUBTLEX_Zipf < 3.5: 평균=55.16%, 중앙값=59.04%, 표준편차=11.14%
#   3.5 <= SUBTLEX_Zipf < 4.0: 평균=41.73%, 중앙값=39.43%, 표준편차=10.98%
#   4.0 <= SUBTLEX_Zipf < 4.5: 평균=24.76%, 중앙값=23.19%, 표준편차=7.84%
#   4.5 <= SUBTLEX_Zipf < 5.0: 평균=11.48%, 중앙값=10.71%, 표준편차=3.73%
#   5.0 <= SUBTLEX_Zipf < 5.5: 평균=4.84%, 중앙값=4.45%, 표준편차=1.55%
#   5.5 <= SUBTLEX_Zipf < 6.0: 평균=1.83%, 중앙값=1.73%, 표준편차=0.55%
#
# SUBTLEX_rank:
#   2.0 <= SUBTLEX_Zipf < 2.5: 평균=75.10%, 중앙값=74.37%, 표준편차=5.39%
#   2.5 <= SUBTLEX_Zipf < 3.0: 평균=54.11%, 중앙값=53.49%, 표준편차=6.61%
#   3.0 <= SUBTLEX_Zipf < 3.5: 평균=32.58%, 중앙값=32.04%, 표준편차=5.46%
#   3.5 <= SUBTLEX_Zipf < 4.0: 평균=17.53%, 중앙값=17.37%, 표준편차=3.45%
#   4.0 <= SUBTLEX_Zipf < 4.5: 평균=8.38%, 중앙값=8.33%, 표준편차=1.88%
#   4.5 <= SUBTLEX_Zipf < 5.0: 평균=3.53%, 중앙값=3.46%, 표준편차=0.88%
#   5.0 <= SUBTLEX_Zipf < 5.5: 평균=1.48%, 중앙값=1.49%, 표준편차=0.32%
#   5.5 <= SUBTLEX_Zipf < 6.0: 평균=0.64%, 중앙값=0.64%, 표준편차=0.14%

# %%
for df in dfs:
    # SUBTLEX가 촘촘하니, 빈도수 정렬.
    df = df[['Word', 'KE_rank', 'SUBTLEX_rank', 'Zipf_KE', 'Zipf_SUBTLEX', 'Freq_KE', 'Freq_SUBTLEX','Age_Of_Acquisition', 'POS']].sort_values('Freq_SUBTLEX', ascending=False)
    df = df.reset_index(drop=True)
    mask_ing = ~(df['Word'].str.contains('ing'))
    mask_s = ~(df['Word'].str.endswith('s'))
    mask_NN = df['POS'] == 'NN'
    # 15개씩 뽑아서 출력.
    df = df[mask_ing & mask_s & mask_NN].reset_index(drop=True)
    #[::int(df.shape[0]/15)]
    print(df)
    break
# Out:
#             Word    KE_rank  SUBTLEX_rank   Zipf_KE  Zipf_SUBTLEX  Freq_KE  \
# 0         capita  87.996086     67.232880  3.418199      2.490180        1
# 1          igloo  69.595793     67.232880  3.594290      2.490180        2
# 2       taxation  69.595793     67.232880  3.594290      2.490180        2
# 3      barbarism  87.996086     67.232880  3.418199      2.490180        1
# 4       mediator  87.996086     67.232880  3.418199      2.490180        1
# ..           ...        ...           ...       ...           ...      ...
# 228    extrovert  87.996086     84.378433  3.418199      2.077128        1
# 229   stagnation  87.996086     84.378433  3.418199      2.077128        1
# 230   beneficent  87.996086     84.378433  3.418199      2.077128        1
# 231  instigation  87.996086     84.378433  3.418199      2.077128        1
# 232    biosphere  69.595793     84.378433  3.594290      2.077128        2
#
#      Freq_SUBTLEX  Age_Of_Acquisition POS
# 0           14.79                 NaN  NN
# 1           14.79                5.42  NN
# 2           14.79               11.42  NN
# 3           14.79               11.61  NN
# 4           14.79               11.05  NN
# ..            ...                 ...  ..
# 228          5.10               12.05  NN
# 229          5.10               13.22  NN
# 230          5.10               15.06  NN
# 231          5.10               12.47  NN
# 232          5.10               13.11  NN
#
# [233 rows x 9 columns]

# %%
word_groups = []
group_names = []

stimuli_groups = []

zipf_range = [(1.5, 2.0), (2.0, 2.5), (2.5, 3.0), (3.0, 3.5), (3.5, 4.0), (4.0, 4.5), (4.5, 5.0), (5.0, 5.5), (5.5, 6.0), (6.0, 6.5)]

for zipf_min, zipf_max in zipf_range:
    # SUBTLEX 기분 zipf range를 정읭.
    zipf_sub_mask = (zipf_min <= ELP_LDT_data['Zipf_SUBTLEX']) & (ELP_LDT_data['Zipf_SUBTLEX'] < zipf_max)
    print(f"{zipf_min} <= Zipf_SUBTLEX < {zipf_max} Words: {len(ELP_LDT_data[zipf_sub_mask])}")
    # 위 range에 해당하는 SUBTLEX rank range.
    sub_rank_min, sub_rank_max = ELP_LDT_data[zipf_sub_mask]['SUBTLEX_rank'].min(), ELP_LDT_data[zipf_sub_mask]['SUBTLEX_rank'].max()
    print(f"SUBTLEX_rank range: {sub_rank_min} ~ {sub_rank_max}")

    # SUBTLEX rank range를 가져와서 적용.
    ke_rank_min, ke_rank_max = sub_rank_min, sub_rank_max
    ke_rank_mask = (ke_rank_min <= ELP_LDT_data['KE_rank']) & (ELP_LDT_data['KE_rank'] < ke_rank_max)
    ELP_LDT_data[ke_rank_mask]['']
    
    print(f"KE_rank range: {ke_rank_min} ~ {ke_rank_max}")
    print(f"{ke_rank_min} <= Zipf_KE < {ke_rank_max} Words: {len(ELP_LDT_data[zipf_ke_mask])}")

    rank_ke_mask = (sub_rank_min <= ELP_LDT_data['SUBTLEX_rank']) & (ELP_LDT_data['SUBTLEX_rank'] < sub_rank_max)
    print(f"{sub_rank_min} <= SUBTLEX_rank < {sub_rank_max} Words: {len(ELP_LDT_data[zipf_ke_mask])}")

    mask_rank_stable = abs(ELP_LDT_data['KE_rank'] - ELP_LDT_data['SUBTLEX_rank']) < 1
    target_words = ELP_LDT_data[mask & mask_pos & mask_rank_stable]
    word_groups.append(target_words['Word'])
    print(f"{zipf_min} <= Zipf_SUBTLEX < {zipf_max} Words: {len(target_words)}")
    group_names.append(f'{zipf_min} <= SUBTLEX_Zipf < {zipf_max}')

rank_columns = ['KE_rank', 'SUBTLEX_rank']

# 함수 실행
fig, plot_df = plot_word_group_ranks_by_corpus(
    df=ELP_LDT_data, 
    word_col='Word', 
    rank_columns=rank_columns,
    word_groups=word_groups, 
    group_names=group_names, 
    figsize=(12, 8)
)
# Out:
# 1.5 <= Zipf_SUBTLEX < 2.0 Words: 0
# 2.0 <= Zipf_SUBTLEX < 2.5 Words: 16
# 2.5 <= Zipf_SUBTLEX < 3.0 Words: 36
# 3.0 <= Zipf_SUBTLEX < 3.5 Words: 83
# 3.5 <= Zipf_SUBTLEX < 4.0 Words: 60
# 4.0 <= Zipf_SUBTLEX < 4.5 Words: 79
# 4.5 <= Zipf_SUBTLEX < 5.0 Words: 66
# 5.0 <= Zipf_SUBTLEX < 5.5 Words: 64
# 5.5 <= Zipf_SUBTLEX < 6.0 Words: 62
# 6.0 <= Zipf_SUBTLEX < 6.5 Words: 34
# Warning: 1.5 <= SUBTLEX_Zipf < 2.0 그룹의 단어들이 데이터에 없습니다.
# Warning: 1.5 <= SUBTLEX_Zipf < 2.0 그룹의 단어들이 데이터에 없습니다.
# === 그룹별 Rank 통계 ===
#
# KE_rank:
#   2.0 <= SUBTLEX_Zipf < 2.5: 평균=69.60%, 중앙값=69.60%, 표준편차=0.00%
#   2.5 <= SUBTLEX_Zipf < 3.0: 평균=53.79%, 중앙값=59.04%, 표준편차=5.99%
#   3.0 <= SUBTLEX_Zipf < 3.5: 평균=31.61%, 중앙값=30.54%, 표준편차=5.59%
#   3.5 <= SUBTLEX_Zipf < 4.0: 평균=17.63%, 중앙값=16.65%, 표준편차=3.56%
#   4.0 <= SUBTLEX_Zipf < 4.5: 평균=7.84%, 중앙값=7.76%, 표준편차=2.03%
#   4.5 <= SUBTLEX_Zipf < 5.0: 평균=3.36%, 중앙값=3.31%, 표준편차=0.94%
#   5.0 <= SUBTLEX_Zipf < 5.5: 평균=1.64%, 중앙값=1.66%, 표준편차=0.49%
#   5.5 <= SUBTLEX_Zipf < 6.0: 평균=1.02%, 중앙값=1.02%, 표준편차=0.35%
#   6.0 <= SUBTLEX_Zipf < 6.5: 평균=0.74%, 중앙값=0.72%, 표준편차=0.32%
#
# SUBTLEX_rank:
#   2.0 <= SUBTLEX_Zipf < 2.5: 평균=69.83%, 중앙값=69.83%, 표준편차=0.00%
#   2.5 <= SUBTLEX_Zipf < 3.0: 평균=53.84%, 중앙값=58.08%, 표준편차=5.75%
#   3.0 <= SUBTLEX_Zipf < 3.5: 평균=31.52%, 중앙값=29.95%, 표준편차=5.57%
#   3.5 <= SUBTLEX_Zipf < 4.0: 평균=17.57%, 중앙값=16.49%, 표준편차=3.55%
#   4.0 <= SUBTLEX_Zipf < 4.5: 평균=7.84%, 중앙값=7.53%, 표준편차=1.91%
#   4.5 <= SUBTLEX_Zipf < 5.0: 평균=3.24%, 중앙값=3.14%, 표준편차=0.79%
#   5.0 <= SUBTLEX_Zipf < 5.5: 평균=1.37%, 중앙값=1.37%, 표준편차=0.31%
#   5.5 <= SUBTLEX_Zipf < 6.0: 평균=0.58%, 중앙값=0.55%, 표준편차=0.15%
#   6.0 <= SUBTLEX_Zipf < 6.5: 평균=0.25%, 중앙값=0.25%, 표준편차=0.06%

# %%
word_groups = []
group_names = []

freq_range = [(3.0, 3.5), (3.5, 4.0), (4.0, 4.5), (4.5, 5.0), (5.0, 5.5), (5.5, 6.0), (6.0, 6.5)]

for freq_min, freq_max in freq_range:
    mask = (freq_min <= ELP_LDT_data['Zipf_KE']) & (ELP_LDT_data['Zipf_KE'] < freq_max)
    print(f"{freq_min} <= Zipf_KE < {freq_max} Words: {len(ELP_LDT_data[mask])}")
    word_groups.append(ELP_LDT_data[mask & mask_pos]['Word'])
    group_names.append(f'{freq_min} <= Zipf_KE < {freq_max}')

rank_columns = ['KE_rank', 'SUBTLEX_rank']

# 함수 실행
fig, plot_df = plot_word_group_ranks_by_corpus(
    df=ELP_LDT_data, 
    word_col='Word', 
    rank_columns=rank_columns,
    word_groups=word_groups, 
    group_names=group_names, 
    figsize=(12, 8)
)
# Out:
# 3.0 <= Zipf_KE < 3.5 Words: 3750
# 3.5 <= Zipf_KE < 4.0 Words: 5616
# 4.0 <= Zipf_KE < 4.5 Words: 3636
# 4.5 <= Zipf_KE < 5.0 Words: 1848
# 5.0 <= Zipf_KE < 5.5 Words: 824
# 5.5 <= Zipf_KE < 6.0 Words: 199
# 6.0 <= Zipf_KE < 6.5 Words: 83
# === 그룹별 Rank 통계 ===
#
# KE_rank:
#   3.0 <= Zipf_KE < 3.5: 평균=88.00%, 중앙값=88.00%, 표준편차=0.00%
#   3.5 <= Zipf_KE < 4.0: 평균=58.11%, 중앙값=59.04%, 표준편차=9.76%
#   4.0 <= Zipf_KE < 4.5: 평균=29.62%, 중앙값=29.05%, 표준편차=6.49%
#   4.5 <= Zipf_KE < 5.0: 평균=12.62%, 중앙값=12.60%, 표준편차=3.27%
#   5.0 <= Zipf_KE < 5.5: 평균=4.48%, 중앙값=4.49%, 표준편차=1.46%
#   5.5 <= Zipf_KE < 6.0: 평균=1.35%, 중앙값=1.35%, 표준편차=0.35%
#   6.0 <= Zipf_KE < 6.5: 평균=0.54%, 중앙값=0.56%, 표준편차=0.12%
#
# SUBTLEX_rank:
#   3.0 <= Zipf_KE < 3.5: 평균=47.77%, 중앙값=46.32%, 표준편차=24.12%
#   3.5 <= Zipf_KE < 4.0: 평균=35.84%, 중앙값=31.32%, 표준편차=21.73%
#   4.0 <= Zipf_KE < 4.5: 평균=21.24%, 중앙값=16.78%, 표준편차=15.80%
#   4.5 <= Zipf_KE < 5.0: 평균=11.12%, 중앙값=7.72%, 표준편차=10.20%
#   5.0 <= Zipf_KE < 5.5: 평균=4.84%, 중앙값=3.15%, 표준편차=5.11%
#   5.5 <= Zipf_KE < 6.0: 평균=1.25%, 중앙값=0.80%, 표준편차=1.38%
#   6.0 <= Zipf_KE < 6.5: 평균=0.33%, 중앙값=0.29%, 표준편차=0.21%

# %%
mask1 = (ELP_LDT_data['KE_rank'] > 90) & (ELP_LDT_data['SUBTLEX_rank'] <20)
ELP_LDT_data[mask1][['Word','KE_rank', 'SUBTLEX_rank', 'Freq_KE', 'Freq_SUBTLEX', 'Zipf_KE', 'Zipf_SUBTLEX']]
# Out:
#               Word  KE_rank  SUBTLEX_rank  Freq_KE  Freq_SUBTLEX   Zipf_KE  \
# 107         accuse    100.0     16.834277        1        290.19  3.418199
# 109       accusing    100.0     18.355447        1        251.94  3.418199
# 185         addict    100.0     17.499084        1        272.85  3.418199
# 303    affirmative    100.0     18.879405        1        241.23  3.418199
# 326         agenda    100.0     14.420125        1        372.81  3.418199
# ...            ...      ...           ...      ...           ...       ...
# 15732        widow    100.0     10.310150        1        617.10  3.418199
# 15793      wishing    100.0     15.304656        1        339.15  3.418199
# 15830          woo    100.0     15.177892        1        343.23  3.418199
# 15925      yankees    100.0     16.194822        1        309.06  3.418199
# 15932           ye    100.0     10.005916        1        641.07  3.418199
#
#        Zipf_SUBTLEX
# 107        3.755974
# 109        3.694815
# 185        3.729310
# 303        3.676026
# 326        3.864449
# ...             ...
# 15732      4.082856
# 15793      3.823468
# 15830      3.828646
# 15925      3.783243
# 15932      4.099380
#
# [384 rows x 7 columns]

# %%
word_groups = []
group_names = []

for i in range(1, 40):
    mask = ELP_LDT_data['Freq_KE'] == i
    print(f"Freq_KE = {i} Words: {len(ELP_LDT_data[mask])}")
    word_groups.append(ELP_LDT_data[mask]['Word'])
    group_names.append(f'Freq_KE = {i} Words')


rank_columns = ['KE_rank', 'SUBTLEX_rank']


# 함수 실행
fig, plot_df = plot_word_group_ranks_by_corpus(
    df=ELP_LDT_data, 
    word_col='Word', 
    rank_columns=rank_columns,
    word_groups=word_groups, 
    group_names=group_names, 
    figsize=(25, 14)
)
# Out:
# Freq_KE = 1 Words: 3750
# Freq_KE = 2 Words: 2038
# Freq_KE = 3 Words: 1335
# Freq_KE = 4 Words: 907
# Freq_KE = 5 Words: 745
# Freq_KE = 6 Words: 591
# Freq_KE = 7 Words: 476
# Freq_KE = 8 Words: 411
# Freq_KE = 9 Words: 346
# Freq_KE = 10 Words: 310
# Freq_KE = 11 Words: 265
# Freq_KE = 12 Words: 216
# Freq_KE = 13 Words: 221
# Freq_KE = 14 Words: 201
# Freq_KE = 15 Words: 181
# Freq_KE = 16 Words: 147
# Freq_KE = 17 Words: 179
# Freq_KE = 18 Words: 138
# Freq_KE = 19 Words: 126
# Freq_KE = 20 Words: 113
# Freq_KE = 21 Words: 99
# Freq_KE = 22 Words: 95
# Freq_KE = 23 Words: 112
# Freq_KE = 24 Words: 86
# Freq_KE = 25 Words: 87
# Freq_KE = 26 Words: 72
# Freq_KE = 27 Words: 85
# Freq_KE = 28 Words: 74
# Freq_KE = 29 Words: 65
# Freq_KE = 30 Words: 61
# Freq_KE = 31 Words: 64
# Freq_KE = 32 Words: 55
# Freq_KE = 33 Words: 59
# Freq_KE = 34 Words: 57
# Freq_KE = 35 Words: 52
# Freq_KE = 36 Words: 49
# Freq_KE = 37 Words: 52
# Freq_KE = 38 Words: 45
# Freq_KE = 39 Words: 42
# === 그룹별 Rank 통계 ===
#
# KE_rank:
#   Freq_KE = 1 Words: 평균=88.00%, 중앙값=88.00%, 표준편차=0.00%
#   Freq_KE = 2 Words: 평균=69.60%, 중앙값=69.60%, 표준편차=0.00%
#   Freq_KE = 3 Words: 평균=59.04%, 중앙값=59.04%, 표준편차=0.00%
#   Freq_KE = 4 Words: 평균=52.04%, 중앙값=52.04%, 표준편차=0.00%
#   Freq_KE = 5 Words: 평균=46.91%, 중앙값=46.91%, 표준편차=0.00%
#   Freq_KE = 6 Words: 평균=42.75%, 중앙값=42.75%, 표준편차=0.00%
#   Freq_KE = 7 Words: 평균=39.43%, 중앙값=39.43%, 표준편차=0.00%
#   Freq_KE = 8 Words: 평균=36.68%, 중앙값=36.68%, 표준편차=0.00%
#   Freq_KE = 9 Words: 평균=34.33%, 중앙값=34.33%, 표준편차=0.00%
#   Freq_KE = 10 Words: 평균=32.30%, 중앙값=32.30%, 표준편차=0.00%
#   Freq_KE = 11 Words: 평균=30.54%, 중앙값=30.54%, 표준편차=0.00%
#   Freq_KE = 12 Words: 평균=29.05%, 중앙값=29.05%, 표준편차=0.00%
#   Freq_KE = 13 Words: 평균=27.70%, 중앙값=27.70%, 표준편차=0.00%
#   Freq_KE = 14 Words: 평균=26.40%, 중앙값=26.40%, 표준편차=0.00%
#   Freq_KE = 15 Words: 평균=25.21%, 중앙값=25.21%, 표준편차=0.00%
#   Freq_KE = 16 Words: 평균=24.19%, 중앙값=24.19%, 표준편차=0.00%
#   Freq_KE = 17 Words: 평균=23.19%, 중앙값=23.19%, 표준편차=0.00%
#   Freq_KE = 18 Words: 평균=22.20%, 중앙값=22.20%, 표준편차=0.00%
#   Freq_KE = 19 Words: 평균=21.38%, 중앙값=21.38%, 표준편차=0.00%
#   Freq_KE = 20 Words: 평균=20.65%, 중앙값=20.65%, 표준편차=0.00%
#   Freq_KE = 21 Words: 평균=20.00%, 중앙값=20.00%, 표준편차=0.00%
#   Freq_KE = 22 Words: 평균=19.40%, 중앙값=19.40%, 표준편차=0.00%
#   Freq_KE = 23 Words: 평균=18.76%, 중앙값=18.76%, 표준편차=0.00%
#   Freq_KE = 24 Words: 평균=18.15%, 중앙값=18.15%, 표준편차=0.00%
#   Freq_KE = 25 Words: 평균=17.61%, 중앙값=17.61%, 표준편차=0.00%
#   Freq_KE = 26 Words: 평균=17.13%, 중앙값=17.13%, 표준편차=0.00%
#   Freq_KE = 27 Words: 평균=16.65%, 중앙값=16.65%, 표준편차=0.00%
#   Freq_KE = 28 Words: 평균=16.15%, 중앙값=16.15%, 표준편차=0.00%
#   Freq_KE = 29 Words: 평균=15.71%, 중앙값=15.71%, 표준편차=0.00%
#   Freq_KE = 30 Words: 평균=15.32%, 중앙값=15.32%, 표준편차=0.00%
#   Freq_KE = 31 Words: 평균=14.94%, 중앙값=14.94%, 표준편차=0.00%
#   Freq_KE = 32 Words: 평균=14.57%, 중앙값=14.57%, 표준편차=0.00%
#   Freq_KE = 33 Words: 평균=14.21%, 중앙값=14.21%, 표준편차=0.00%
#   Freq_KE = 34 Words: 평균=13.86%, 중앙값=13.86%, 표준편차=0.00%
#   Freq_KE = 35 Words: 평균=13.52%, 중앙값=13.52%, 표준편차=0.00%
#   Freq_KE = 36 Words: 평균=13.21%, 중앙값=13.21%, 표준편차=0.00%
#   Freq_KE = 37 Words: 평균=12.90%, 중앙값=12.90%, 표준편차=0.00%
#   Freq_KE = 38 Words: 평균=12.60%, 중앙값=12.60%, 표준편차=0.00%
#   Freq_KE = 39 Words: 평균=12.33%, 중앙값=12.33%, 표준편차=0.00%
#
# SUBTLEX_rank:
#   Freq_KE = 1 Words: 평균=51.66%, 중앙값=50.98%, 표준편차=23.87%
#   Freq_KE = 2 Words: 평균=44.41%, 중앙값=42.89%, 표준편차=22.66%
#   Freq_KE = 3 Words: 평균=38.01%, 중앙값=33.99%, 표준편차=21.09%
#   Freq_KE = 4 Words: 평균=35.62%, 중앙값=31.32%, 표준편차=20.21%
#   Freq_KE = 5 Words: 평균=32.85%, 중앙값=29.29%, 표준편차=19.48%
#   Freq_KE = 6 Words: 평균=31.11%, 중앙값=26.74%, 표준편차=19.61%
#   Freq_KE = 7 Words: 평균=27.72%, 중앙값=23.61%, 표준편차=17.59%
#   Freq_KE = 8 Words: 평균=27.42%, 중앙값=23.85%, 표준편차=17.51%
#   Freq_KE = 9 Words: 평균=24.53%, 중앙값=21.37%, 표준편차=16.04%
#   Freq_KE = 10 Words: 평균=25.10%, 중앙값=21.16%, 표준편차=16.00%
#   Freq_KE = 11 Words: 평균=22.72%, 중앙값=18.25%, 표준편차=16.27%
#   Freq_KE = 12 Words: 평균=19.83%, 중앙값=16.94%, 표준편차=12.56%
#   Freq_KE = 13 Words: 평균=21.75%, 중앙값=17.05%, 표준편차=16.80%
#   Freq_KE = 14 Words: 평균=21.08%, 중앙값=17.96%, 표준편차=14.36%
#   Freq_KE = 15 Words: 평균=20.57%, 중앙값=16.97%, 표준편차=15.14%
#   Freq_KE = 16 Words: 평균=20.51%, 중앙값=16.57%, 표준편차=15.69%
#   Freq_KE = 17 Words: 평균=17.06%, 중앙값=13.19%, 표준편차=12.16%
#   Freq_KE = 18 Words: 평균=16.84%, 중앙값=13.40%, 표준편차=12.96%
#   Freq_KE = 19 Words: 평균=18.33%, 중앙값=14.81%, 표준편차=12.48%
#   Freq_KE = 20 Words: 평균=17.73%, 중앙값=13.57%, 표준편차=14.77%
#   Freq_KE = 21 Words: 평균=16.56%, 중앙값=12.98%, 표준편차=12.12%
#   Freq_KE = 22 Words: 평균=17.31%, 중앙값=12.52%, 표준편차=13.59%
#   Freq_KE = 23 Words: 평균=16.44%, 중앙값=12.49%, 표준편차=12.20%
#   Freq_KE = 24 Words: 평균=14.66%, 중앙값=11.35%, 표준편차=10.67%
#   Freq_KE = 25 Words: 평균=17.41%, 중앙값=12.11%, 표준편차=13.16%
#   Freq_KE = 26 Words: 평균=11.50%, 중앙값=8.15%, 표준편차=9.47%
#   Freq_KE = 27 Words: 평균=15.86%, 중앙값=13.44%, 표준편차=11.00%
#   Freq_KE = 28 Words: 평균=11.76%, 중앙값=11.31%, 표준편차=7.75%
#   Freq_KE = 29 Words: 평균=14.67%, 중앙값=12.31%, 표준편차=14.50%
#   Freq_KE = 30 Words: 평균=12.45%, 중앙값=8.79%, 표준편차=8.10%
#   Freq_KE = 31 Words: 평균=15.28%, 중앙값=12.48%, 표준편차=11.36%
#   Freq_KE = 32 Words: 평균=15.31%, 중앙값=12.90%, 표준편차=10.59%
#   Freq_KE = 33 Words: 평균=14.63%, 중앙값=11.88%, 표준편차=12.63%
#   Freq_KE = 34 Words: 평균=13.46%, 중앙값=10.38%, 표준편차=11.82%
#   Freq_KE = 35 Words: 평균=13.33%, 중앙값=8.34%, 표준편차=13.62%
#   Freq_KE = 36 Words: 평균=12.01%, 중앙값=9.26%, 표준편차=10.51%
#   Freq_KE = 37 Words: 평균=11.05%, 중앙값=9.24%, 표준편차=8.49%
#   Freq_KE = 38 Words: 평균=12.43%, 중앙값=9.06%, 표준편차=9.71%
#   Freq_KE = 39 Words: 평균=12.44%, 중앙값=9.20%, 표준편차=9.37%

# %%
freq_min, freq_max = 6.0, 6.5
mask_pos = (ELP_LDT_data['POS'].str.contains('NN')) #& ~(ELP_LDT_data['POS'].str.contains('V'))
mask_zipf_range = (freq_min <= ELP_LDT_data['Zipf_SUBTLEX']) & (ELP_LDT_data['Zipf_SUBTLEX'] < freq_max)
mask_rank_stable = abs(ELP_LDT_data['KE_rank'] - ELP_LDT_data['SUBTLEX_rank']) <= 5
words = ['back', 'down', 'good','little', 'love', 'man', 'need','time',  'people', 'thing', 'one', 'thank']
target_words = ELP_LDT_data[mask & mask_pos & mask_rank_stable]

print(f"candidates: {len(target_words)}")
print(f'{len(words)/15}')
target_words[['Word', 'Zipf_KE', 'Zipf_SUBTLEX', 'KE_rank', 'SUBTLEX_rank', 'Freq_KE', 'Freq_SUBTLEX', 'POS']]
# Out:
# candidates: 20
# 0.8
#                Word   Zipf_KE  Zipf_SUBTLEX    KE_rank  SUBTLEX_rank  Freq_KE  \
# 22           abroad  4.418199      3.691298  21.384455     18.448407       19
# 683      approaches  4.418199      3.526947  21.384455     22.906279       19
# 850     assignments  4.418199      3.549548  21.384455     22.300628       19
# 2735     comparison  4.418199      3.566348  21.384455     21.868222       19
# 4211   distribution  4.418199      3.490675  21.384455     24.020395       19
# 4910            era  4.418199      3.757493  21.384455     16.777937       19
# 5091      exercises  4.418199      3.537138  21.384455     22.644300       19
# 6001        gabriel  4.418199      3.757493  21.384455     16.777937       19
# 6522           hare  4.418199      3.583655  21.384455     21.341446       19
# 9655        olympic  4.418199      3.603552  21.384455     20.768191       19
# 10090         pasta  4.418199      3.628737  21.384455     20.087890       19
# 10895        prizes  4.418199      3.449557  21.384455     25.234514       19
# 11106    publishing  4.418199      3.581387  21.384455     21.407645       19
# 11334         ratio  4.418199      3.509860  21.384455     23.437280       19
# 11525    reflection  4.418199      3.701765  21.384455     18.179385       19
# 11952       reviews  4.418199      3.473527  21.384455     24.534494       19
# 12035         rises  4.418199      3.605707  21.384455     20.709034       19
# 12540        select  4.418199      3.549548  21.384455     22.300628       19
# 13748        styles  4.418199      3.429057  21.384455     25.981014       19
# 14263         tends  4.418199      3.425815  21.384455     26.075382       19
#
#        Freq_SUBTLEX       POS
# 22           249.90     RB|NN
# 683          170.85     NN|VB
# 850          180.03        NN
# 2735         187.17        NN
# 4211         157.08        NN
# 4910         291.21        NN
# 5091         174.93     NN|VB
# 6001         291.21        NN
# 6522         194.82        NN
# 9655         204.00     NN|JJ
# 10090        216.24        NN
# 10895        142.80     NN|VB
# 11106        193.80     NN|VB
# 11334        164.22        NN
# 11525        256.02        NN
# 11952        150.96     NN|VB
# 12035        205.02     VB|NN
# 12540        180.03  VB|NN|JJ
# 13748        136.17        NN
# 14263        135.15     VB|NN

# %%
hf1_words['Zipf_KE'].mean(), hf2_words['Zipf_KE'].mean(), lf_words['Zipf_KE'].mean()
# Out:
# (np.float64(4.390201655822801),
#  np.float64(3.418198770837067),
#  np.float64(3.418198770837067))

# %%
hf1_words
# Out:
# 715      watching
# 721        finish
# 731        choice
# 733      birthday
# 738         smart
# 741         month
# 747        needed
# 761        return
# 763       message
# 766     afternoon
# 772           box
# 776          kept
# 785          dark
# 800       wearing
# 804         voice
# 808    interested
# 814        bought
# 815          card
# 822    completely
# 823           ran
# 826      finished
# 827          born
# 831          lead
# 842       amazing
# Name: Word, dtype: object

# %%
hf2_words
# Out:
# 730           blow
# 778           fool
# 788          swear
# 801         johnny
# 844          danny
# 872          angel
# 873           mess
# 876        killing
# 883        forgive
# 884          drunk
# 885          henry
# 887        figured
# 889     girlfriend
# 890          folks
# 895           beer
# 913           kick
# 925      boyfriend
# 935          mommy
# 941       upstairs
# 945           jail
# 973          billy
# 980           holy
# 1000         idiot
# 1002        prison
# Name: Word, dtype: object

# %%
lf_words
# Out:
# 14978        locomotion
# 14983          balinese
# 15079             spiny
# 15116        stubbornly
# 15118        attainable
# 15132     intersections
# 15184        languished
# 15186         stammered
# 15198            lordly
# 15201          longings
# 15210          livelier
# 15228      internalized
# 15253    justifications
# 15304            styled
# 15326      subjectively
# 15346       structuring
# 15352       strategists
# 15359           jaywalk
# 15367      irresistibly
# 15382       shallowness
# 15385       compensates
# 15396         shapeless
# 15413     modernization
# 15419       instigation
# Name: Word, dtype: object

# %%
# Zipf-score 기준으로 word 개수 세보기
# 이걸 축으로 삼기는 조금 힘들라나.? 그냥 해보자.
def count_words_by_zipf_score(df, zipf_column):
    min_count = int(df[zipf_column].describe()['min'])
    max_count = int(df[zipf_column].describe()['max'])

    for i in range(min_count, max_count+1):
        mask = (df[zipf_column] >= i) & (df[zipf_column] < i+1)
        print(f"{i} <= {zipf_column} < {i+1} : {len(df[mask])} words")

count_words_by_zipf_score(ELP_LDT_data, 'Zipf_SUBTLEX')
count_words_by_zipf_score(ELP_LDT_data, 'Zipf_KE')
# Out:
# 1 <= Zipf_SUBTLEX < 2 : 525 words
# 2 <= Zipf_SUBTLEX < 3 : 4303 words
# 3 <= Zipf_SUBTLEX < 4 : 7217 words
# 4 <= Zipf_SUBTLEX < 5 : 3235 words
# 5 <= Zipf_SUBTLEX < 6 : 588 words
# 6 <= Zipf_SUBTLEX < 7 : 118 words
# 7 <= Zipf_SUBTLEX < 8 : 9 words
# 3 <= Zipf_KE < 4 : 9366 words
# 4 <= Zipf_KE < 5 : 5484 words
# 5 <= Zipf_KE < 6 : 1023 words
# 6 <= Zipf_KE < 7 : 111 words
# 7 <= Zipf_KE < 8 : 11 words

# %%
# Zipf-score 기준으로 word 개수 세보기
# 이걸 축으로 삼기는 조금 힘들라나.? 그냥 해보자.
def count_words_by_zipf_score(df, zipf_column):
    min_count = int(df[zipf_column].describe()['min'])
    #max_count = int(df[zipf_column].describe()['max'])
    max_count = 10

    for i in range(min_count, max_count+1):
        mask = (df[zipf_column] >= i) & (df[zipf_column] < i+1)
        print(f"{i} <= {zipf_column} < {i+1} : {len(df[mask])} words")

count_words_by_zipf_score(ELP_LDT_data, 'Freq_SUBTLEX')
count_words_by_zipf_score(ELP_LDT_data, 'Freq_KE')
print(len(ELP_LDT_data))
# Out:
# 1 <= Freq_SUBTLEX < 2 : 130 words
# 2 <= Freq_SUBTLEX < 3 : 126 words
# 3 <= Freq_SUBTLEX < 4 : 143 words
# 4 <= Freq_SUBTLEX < 5 : 126 words
# 5 <= Freq_SUBTLEX < 6 : 125 words
# 6 <= Freq_SUBTLEX < 7 : 128 words
# 7 <= Freq_SUBTLEX < 8 : 152 words
# 8 <= Freq_SUBTLEX < 9 : 113 words
# 9 <= Freq_SUBTLEX < 10 : 120 words
# 10 <= Freq_SUBTLEX < 11 : 129 words
# 1 <= Freq_KE < 2 : 3750 words
# 2 <= Freq_KE < 3 : 2038 words
# 3 <= Freq_KE < 4 : 1335 words
# 4 <= Freq_KE < 5 : 907 words
# 5 <= Freq_KE < 6 : 745 words
# 6 <= Freq_KE < 7 : 591 words
# 7 <= Freq_KE < 8 : 476 words
# 8 <= Freq_KE < 9 : 411 words
# 9 <= Freq_KE < 10 : 346 words
# 10 <= Freq_KE < 11 : 310 words
# 15995

# %%
mask = ELP_LDT_data['Zipf_KE'] < ELP_LDT_data['Zipf_SUBTLEX']
ELP_LDT_data[['Word', 'Zipf_KE', 'Zipf_SUBTLEX']][mask]
# Out:
#              Word   Zipf_KE  Zipf_SUBTLEX
# 2           aaron  4.020259      4.165786
# 39          abide  3.418199      3.435468
# 49       abnormal  3.418199      3.464692
# 53         aboard  4.117169      4.425059
# 74          about  6.503132      6.559455
# ...           ...       ...           ...
# 40376         you  7.129711      7.621137
# 40389        your  6.640134      6.808618
# 40390       yours  4.661237      5.310591
# 40391    yourself  5.482657      5.637207
# 40392  yourselves  3.594290      4.462059
#
# [2751 rows x 3 columns]

# %%
mask = ELP_LDT_data['Zipf_KE'] > ELP_LDT_data['Zipf_SUBTLEX']
ELP_LDT_data[['Word', 'Zipf_KE', 'Zipf_SUBTLEX']][mask]
# Out:
#               Word   Zipf_KE  Zipf_SUBTLEX
# 0                a  7.360356      7.309323
# 5          abandon  4.020259      3.908903
# 6        abandoned  4.231112      4.123533
# 7       abandoning  3.719229      3.232264
# 8      abandonment  3.594290      2.990420
# ...            ...       ...           ...
# 40436      zombies  3.719229      3.355319
# 40437         zone  4.418199      4.303419
# 40439        zones  4.372441      3.249692
# 40441          zoo  4.622319      4.135124
# 40442    zoologist  3.594290      2.413686
#
# [13244 rows x 3 columns]

# %%
ELP_LDT_data[['Word', 'Zipf_KE', 'Zipf_SUBTLEX']].describe()
# Out:
#             Zipf_KE  Zipf_SUBTLEX
# count  15995.000000  15995.000000
# mean       4.008162      3.471007
# std        0.587020      0.850980
# min        3.418199      1.597149
# 25%        3.594290      2.885637
# 50%        3.816139      3.405841
# 75%        4.347618      3.991462
# max        7.700413      7.621137

# %%
mask1 = KE_E_final_df['Freq_KE'] > 0
mask2 = KE_E_final_df['Freq_SUBTLEX'] > 0
mask3 = KE_E_final_df['Freq_HAL'] > 0
mask4 = KE_E_final_df['Freq_KF'] > 0

print("="*20)
print(f"KE: {KE_E_final_df[mask1]['RFreq_KE'].mean()}")
print(f"SUBTLEX: {KE_E_final_df[mask2]['RFreq_SUBTLEX'].mean()}")
print(f"HAL: {KE_E_final_df[mask3]['RFreq_HAL(130)'].mean()}")
print(f"KF: {KE_E_final_df[mask4]['RFreq_KF'].mean()}")
print("")
print("="*20)
print(f"KE: {KE_E_final_df[mask1]['Zipf_KE'].mean()}")
print(f"SUBTLEX: {KE_E_final_df[mask2]['Zipf_SUBTLEX'].mean()}")
print(f"HAL: {KE_E_final_df[mask3]['Zipf_HAL(130)'].mean()}")
print(f"KF: {KE_E_final_df[mask4]['Zipf_KF'].mean()}")
# Out:
# ====================
# KE: 58.50978886829159
# SUBTLEX: 25.233352949457977
# HAL: 83.98334869934271
# KF: 29.43701349736842
#
# ====================
# KE: 4.001011008623093
# SUBTLEX: 2.951035343530784
# HAL: 3.6057703868895574
# KF: 3.7340869352506525

# %%
ELP_LDT_data
# Out:
#              Word  Freq_KE  Freq_KE(EXAM)  Freq_KE(TEXTBOOK)  Ortho_N_KE  \
# 0               a    17505         9773.0             7732.0         1.0
# 2           aaron        7            1.0                6.0         1.0
# 5         abandon        7            5.0                2.0         0.0
# 6       abandoned       12            5.0                7.0         0.0
# 7      abandoning        3            3.0                NaN         0.0
# ...           ...      ...            ...                ...         ...
# 40436     zombies        3            NaN                3.0         0.0
# 40437        zone       19            6.0               13.0         7.0
# 40439       zones       17            8.0                9.0         4.0
# 40441         zoo       31           21.0               10.0         4.0
# 40442   zoologist        2            2.0                NaN         0.0
#
#        Ortho_N_KE(EXAM)  Ortho_N_KE(TEXTBOOK)  OLD_KE  OLD_KE(EXAM)  \
# 0                   1.0                   1.0    1.45          1.45
# 2                   1.0                   0.0    1.85          1.95
# 5                   0.0                   0.0    2.90          3.05
# 6                   0.0                   0.0    3.50          3.50
# 7                   0.0                   NaN    3.60          3.60
# ...                 ...                   ...     ...           ...
# 40436               NaN                   0.0    2.60           NaN
# 40437               7.0                   7.0    1.40          1.40
# 40439               4.0                   4.0    1.60          1.60
# 40441               1.0                   4.0    1.70          1.85
# 40442               0.0                   NaN    3.90          3.90
#
#        OLD_KE(TEXTBOOK)  ...  RFreq_HAL(130)  RFreq_HAL(160)  RFreq_SUBTLEX  \
# 0                  1.45  ...    81620.200000     66316.41250       20415.27
# 2                  2.00  ...       83.123077        67.53750          14.65
# 5                  3.00  ...       28.930769        23.50625           8.10
# 6                  3.60  ...       39.692308        32.25000          13.29
# 7                   NaN  ...        7.730769         6.28125           1.69
# ...                 ...  ...             ...             ...            ...
# 40436              2.65  ...       19.907692        16.17500           2.25
# 40437              1.40  ...      133.076923       108.12500          20.12
# 40439              1.60  ...       26.061538        21.17500           1.76
# 40441              1.70  ...       33.207692        26.98125          13.65
# 40442               NaN  ...        2.315385         1.88125           0.24
#
#         Zipf_KE  Zipf_KE(EXAM)  Zipf_KE(TEXTBOOK)   Zipf_KF  Zipf_HAL(130)  \
# 0      7.350050       7.319896           7.338816  7.344811       7.911662
# 2      4.009953       3.630854           4.295566  3.881702       4.919627
# 5      4.009953       4.107975           3.927590  4.233884       4.461340
# 6      4.220806       4.107975           4.353558  4.393585       4.598655
# 7      3.708923       3.931884                NaN  3.881702       3.888519
# ...         ...            ...                ...       ...            ...
# 40436  3.708923            NaN           4.052528  3.279642       4.299053
# 40437  4.407893       4.174922           4.596596  4.057793       5.123993
# 40439  4.362135       4.284066           4.450468  3.580672       4.415993
# 40441  4.612013       4.672246           4.491861  3.978612       4.521204
# 40442  3.583984       3.806945                NaN  3.455733       3.365928
#
#        Zipf_HAL(160)  Zipf_SUBTLEX
# 0           7.821511      7.309611
# 2           4.829475      4.166074
# 5           4.371189      3.909190
# 6           4.508504      4.123821
# 7           3.798368      3.232552
# ...              ...           ...
# 40436       4.208902      3.355606
# 40437       5.033841      4.303706
# 40439       4.325842      3.249980
# 40441       4.431053      4.135411
# 40442       3.275777      2.413973
#
# [16353 rows x 57 columns]

# %% [markdown]
# # ANOVA & R^2

# %%
from scipy import stats
def comprehensive_analysis(df, independent_var, dependent_var):
    """
    독립변수와 종속변수의 관계를 종합적으로 분석
    """
    print("=== 변수 타입 확인 ===")
    print(f"독립변수 타입: {df[independent_var].dtype}")
    print(f"종속변수 타입: {df[dependent_var].dtype}")
    print()
    
    # 연속형 vs 연속형
    if df[independent_var].dtype in ['float64', 'int64'] and df[dependent_var].dtype in ['float64', 'int64']:
        print("=== 연속형 변수 간 관계 분석 ===")
        
        # 상관계수
        correlation = df[[independent_var, dependent_var]].corr().iloc[0,1]
        print(f"피어슨 상관계수: {correlation:.4f}")
        
        # R²
        from sklearn.linear_model import LinearRegression
        X = df[[independent_var]].values
        y = df[dependent_var].values
        model = LinearRegression().fit(X, y)
        r2 = model.score(X, y)
        print(f"R² (결정계수): {r2:.4f}")
        print(f"설명력: {r2*100:.2f}%")
        
    # 범주형 vs 연속형
    elif df[independent_var].dtype == 'object' and df[dependent_var].dtype in ['float64', 'int64']:
        print("=== 범주형 vs 연속형 관계 분석 ===")
        
        # ANOVA
        groups = [group[dependent_var].values for name, group in df.groupby(independent_var)]
        f_stat, p_value = stats.f_oneway(*groups)
        print(f"F-통계량: {f_stat:.4f}")
        print(f"p-value: {p_value:.4f}")
        
        # 그룹별 평균과 표준편차
        group_stats = df.groupby(independent_var)[dependent_var].agg(['mean', 'std', 'count'])
        print("\n그룹별 통계:")
        print(group_stats)
        
        # eta-squared (효과크기)
        ss_between = sum([len(group) * (group.mean() - df[dependent_var].mean())**2 
                         for name, group in df.groupby(independent_var)])
        ss_total = ((df[dependent_var] - df[dependent_var].mean())**2).sum()
        eta_squared = ss_between / ss_total
        print(f"Eta-squared (효과크기): {eta_squared:.4f}")
        print(f"설명력: {eta_squared*100:.2f}%")

# %%
def analyze_corpus_frequency_rt(df, rt_column, frequency_columns):
    """
    여러 코퍼스 빈도와 반응시간 간의 상관관계 분석
    """
    print("=== 코퍼스별 빈도-반응시간 상관관계 ===")
    
    correlations = {}
    for freq_col in frequency_columns:
        # 결측값 제거
        clean_data = df[[rt_column, freq_col]].dropna()
        
        if len(clean_data) > 0:
            corr = clean_data[rt_column].corr(clean_data[freq_col])
            correlations[freq_col] = corr
            print(f"{freq_col}: r = {corr:.4f} (n = {len(clean_data)})")
    
    # 가장 높은 상관관계를 가진 코퍼스
    best_corpus = max(correlations, key=correlations.get)
    print(f"\n가장 높은 상관관계: {best_corpus} (r = {correlations[best_corpus]:.4f})")
    
    return correlations

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import numpy as np

def compare_corpus_explanatory_power(df, rt_column, frequency_columns):
    """
    각 코퍼스가 반응시간을 얼마나 잘 설명하는지 R²로 비교
    """
    print("=== 코퍼스별 설명력 (R²) 비교 ===")
    
    r2_scores = {}
    for freq_col in frequency_columns:
        # 결측값 제거
        clean_data = df[[rt_column, freq_col]].dropna()
        
        if len(clean_data) > 2:
            X = clean_data[[freq_col]].values
            y = clean_data[rt_column].values
            
            # 선형회귀 모델
            model = LinearRegression().fit(X, y)
            r2 = model.score(X, y)
            r2_scores[freq_col] = r2
            
            print(f"{freq_col}: R² = {r2:.4f} ({r2*100:.2f}%)")
    
    # 가장 높은 설명력을 가진 코퍼스
    best_corpus = max(r2_scores, key=r2_scores.get)
    print(f"\n가장 높은 설명력: {best_corpus} (R² = {r2_scores[best_corpus]:.4f})")
    
    return r2_scores

# %%
from sklearn.feature_selection import f_regression
import statsmodels.api as sm

def stepwise_regression(df, rt_column, frequency_columns):
    """
    단계적 회귀분석으로 가장 중요한 변수들 선택
    """
    print("=== 단계적 회귀분석 ===")
    
    # 결측값 제거
    clean_data = df[[rt_column] + frequency_columns].dropna()
    
    if len(clean_data) > len(frequency_columns):
        X = clean_data[frequency_columns]
        y = clean_data[rt_column]
        
        # F-통계량으로 변수 중요도 계산
        f_scores, p_values = f_regression(X, y)
        
        # 결과 정리
        variable_importance = pd.DataFrame({
            'Variable': frequency_columns,
            'F_Score': f_scores,
            'P_Value': p_values
        }).sort_values('F_Score', ascending=False)
        
        print("변수 중요도 (F-통계량 기준):")
        print(variable_importance)
        
        # 가장 중요한 변수들로 회귀분석
        best_variables = variable_importance.head(3)['Variable'].tolist()
        print(f"\n상위 3개 변수로 회귀분석: {best_variables}")
        
        X_best = X[best_variables]
        model = LinearRegression().fit(X_best, y)
        print(f"R²: {model.score(X_best, y):.4f}")

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
import pandas as pd

def multiple_regression_analysis(df, rt_column, frequency_columns):
    """
    여러 코퍼스를 동시에 고려한 다중회귀분석
    """
    print("=== 다중회귀분석 ===")
    
    # 결측값 제거
    clean_data = df[[rt_column] + frequency_columns].dropna()
    
    if len(clean_data) > len(frequency_columns):
        X = clean_data[frequency_columns].values
        y = clean_data[rt_column].values
        
        # 표준화
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X)
        
        # 다중회귀 모델
        model = LinearRegression().fit(X_scaled, y)
        
        # 결과 출력
        print(f"전체 R²: {model.score(X_scaled, y):.4f}")
        print("\n표준화된 회귀계수:")
        for i, col in enumerate(frequency_columns):
            print(f"{col}: β = {model.coef_[i]:.4f}")
        
        # 각 변수의 고유 기여도
        print("\n각 변수의 고유 기여도:")
        for i, col in enumerate(frequency_columns):
            # 해당 변수만으로 회귀분석
            single_model = LinearRegression().fit(X_scaled[:, i:i+1], y)
            unique_r2 = single_model.score(X_scaled[:, i:i+1], y)
            print(f"{col}: 고유 R² = {unique_r2:.4f}")

# %%
def comprehensive_corpus_analysis(df, rt_column, frequency_columns):
    """
    코퍼스 빈도와 반응시간 간의 종합적 분석
    """
    print("=" * 60)
    print("코퍼스 빈도-반응시간 종합 분석")
    print("=" * 60)
    
    # 1. 기본 상관관계 분석
    correlations = analyze_corpus_frequency_rt(df, rt_column, frequency_columns)
    
    print("\n" + "=" * 60)
    
    # 2. 설명력 비교
    r2_scores = compare_corpus_explanatory_power(df, rt_column, frequency_columns)
    
    print("\n" + "=" * 60)
    
    # 3. 다중회귀분석
    #multiple_regression_analysis(df, rt_column, frequency_columns)
    
    print("\n" + "=" * 60)
    
    # 4. 단계적 회귀분석
    #stepwise_regression(df, rt_column, frequency_columns)
    
    # 결과 요약
    print("\n" + "=" * 60)
    print("분석 결과 요약")
    print("=" * 60)
    
    # 상관관계 기준 상위 3개
    top_corr = sorted(correlations.items(), key=lambda x: abs(x[1]), reverse=True)[:3]
    print("상관관계 기준 상위 3개:")
    for corpus, corr in top_corr:
        print(f"  {corpus}: r = {corr:.4f}")
    
    # 설명력 기준 상위 3개
    top_r2 = sorted(r2_scores.items(), key=lambda x: x[1], reverse=True)[:3]
    print("\n설명력 기준 상위 3개:")
    for corpus, r2 in top_r2:
        print(f"  {corpus}: R² = {r2:.4f} ({r2*100:.2f}%)")
    
    return {
        'correlations': correlations,
        'r2_scores': r2_scores
    }

# %%
frequency_columns = ['Zipf_SUBTLEX', 'Zipf_HAL(160)', 'Zipf_KE', 'Zipf_KF',  'Freq_SUBTLEX', 'Freq_HAL', 'Freq_KE', 'Freq_KF']
rt_column = 'LDT_RT_MEAN'  # 반응시간 컬럼명

results = comprehensive_corpus_analysis(ELP_LDT_data, rt_column, frequency_columns)
# Out:
# ============================================================
# 코퍼스 빈도-반응시간 종합 분석
# ============================================================
# === 코퍼스별 빈도-반응시간 상관관계 ===
# Zipf_SUBTLEX: r = -0.5871 (n = 16353)
# Zipf_HAL(160): r = -0.5501 (n = 16353)
# Zipf_KE: r = -0.4590 (n = 16353)
# Zipf_KF: r = -0.4565 (n = 16353)
# Freq_SUBTLEX: r = -0.0742 (n = 16353)
# Freq_HAL: r = -0.0714 (n = 16353)
# Freq_KE: r = -0.0743 (n = 16353)
# Freq_KF: r = -0.0573 (n = 16353)
#
# 가장 높은 상관관계: Freq_KF (r = -0.0573)
#
# ============================================================
# === 코퍼스별 설명력 (R²) 비교 ===
# Zipf_SUBTLEX: R² = 0.3447 (34.47%)
# Zipf_HAL(160): R² = 0.3026 (30.26%)
# Zipf_KE: R² = 0.2107 (21.07%)
# Zipf_KF: R² = 0.2084 (20.84%)
# Freq_SUBTLEX: R² = 0.0055 (0.55%)
# Freq_HAL: R² = 0.0051 (0.51%)
# Freq_KE: R² = 0.0055 (0.55%)
# Freq_KF: R² = 0.0033 (0.33%)
#
# 가장 높은 설명력: Zipf_SUBTLEX (R² = 0.3447)
#
# ============================================================
#
# ============================================================
#
# ============================================================
# 분석 결과 요약
# ============================================================
# 상관관계 기준 상위 3개:
#   Zipf_SUBTLEX: r = -0.5871
#   Zipf_HAL(160): r = -0.5501
#   Zipf_KE: r = -0.4590
#
# 설명력 기준 상위 3개:
#   Zipf_SUBTLEX: R² = 0.3447 (34.47%)
#   Zipf_HAL(160): R² = 0.3026 (30.26%)
#   Zipf_KE: R² = 0.2107 (21.07%)
