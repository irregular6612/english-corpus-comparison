# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import os

# %%
proj_dir = os.path.join(Path.home(), 'Documents', 'WorkSpace', 'corpus-comparison')
analysis_dir = os.path.join(proj_dir, 'analysis')
corpora_dir = os.path.join(proj_dir, 'corpora')

print(f"Project directory: {proj_dir}")
print(f"Analysis directory: {analysis_dir}")
print(f"Corpora directory: {corpora_dir}")
# Out:
# Project directory: /Users/bagjuhyeon/Documents/WorkSpace/corpus-comparison
# Analysis directory: /Users/bagjuhyeon/Documents/WorkSpace/corpus-comparison/analysis
# Corpora directory: /Users/bagjuhyeon/Documents/WorkSpace/corpus-comparison/corpora

# %% [markdown]
# # File-processing

# %% [markdown]
# 기존 처리된 파일에서 LDT Obs가 빠져서 이것만 merging 이후 필요한 것만 뽑아서 다시 정리.

# %% [markdown]
# ## convert csv -> xlsx

# %%
ELP_LDT_data_path = os.path.join(corpora_dir, 'behavior-exp', 'ELP-LDT.csv')

if os.path.exists(ELP_LDT_data_path):
    df = pd.read_csv(ELP_LDT_data_path)
    df.to_excel(os.path.join(corpora_dir, 'behavior-exp', 'ELP-LDT.xlsx'), index=False)
    print("Conversion complete: word_stimuli.csv -> word_stimuli.xlsx")
else:
    raise FileNotFoundError(f"File not found: {ELP_LDT_data_path}")
# Out:
# Conversion complete: word_stimuli.csv -> word_stimuli.xlsx

# %%
ELP_LDT_data = pd.read_excel(os.path.join(corpora_dir, 'behavior-exp', 'ELP-LDT.xlsx'))
ELP_LDT_data
# Out:
#            Word  Length    Freq_HAL  Log_Freq_HAL     SUBTLWF I_Mean_RT  \
# 0             a       1  10,610,626        16.177  20,415.270   798.917
# 1           aah       3         222         5.403      52.710   816.429
# 2         Aaron       5      10,806         9.288      14.650   736.062
# 3         aback       5         387         5.958       0.290   796.267
# 4        abacus       6         513         6.240       0.240   964.400
# ...         ...     ...         ...           ...         ...       ...
# 40476      zoom       4       4,920         8.501       3.550   549.758
# 40477   zooming       7         523         6.260       0.630   709.690
# 40478     zooms       5         385         5.953       0.060   666.933
# 40479  zucchini       8         314         5.749       0.960   848.679
# 40480    Zurich       6       1,770         7.479       2.430   763.000
#
#       I_Zscore     I_SD Obs  I_Mean_Accuracy
# 0       -0.013  333.849  24             0.73
# ...

# %% [markdown]
# lower

# %%
ELP_LDT_data['Word'] = ELP_LDT_data['Word'].str.lower()
ELP_LDT_data
# Out:
#            Word  Length    Freq_HAL  Log_Freq_HAL     SUBTLWF I_Mean_RT  \
# 0             a       1  10,610,626        16.177  20,415.270   798.917
# 1           aah       3         222         5.403      52.710   816.429
# 2         aaron       5      10,806         9.288      14.650   736.062
# 3         aback       5         387         5.958       0.290   796.267
# 4        abacus       6         513         6.240       0.240   964.400
# ...         ...     ...         ...           ...         ...       ...
# 40476      zoom       4       4,920         8.501       3.550   549.758
# 40477   zooming       7         523         6.260       0.630   709.690
# 40478     zooms       5         385         5.953       0.060   666.933
# 40479  zucchini       8         314         5.749       0.960   848.679
# 40480    zurich       6       1,770         7.479       2.430   763.000
#
#       I_Zscore     I_SD Obs  I_Mean_Accuracy
# 0       -0.013  333.849  24             0.73
# ...

# %%
remove_cols = ELP_LDT_data.columns.to_list()
remove_cols.remove('Obs')
remove_cols.remove('Word')
remove_cols
# Out:
# ['Length',
#  'Freq_HAL',
#  'Log_Freq_HAL',
#  'SUBTLWF',
#  'I_Mean_RT',
#  'I_Zscore',
#  'I_SD',
#  'I_Mean_Accuracy']

# %% [markdown]
# left only obs info

# %%
ELP_LDT_data.drop(columns=remove_cols, inplace=True)
ELP_LDT_data
# Out:
#            Word Obs
# 0             a  24
# 1           aah  21
# 2         aaron  32
# 3         aback  15
# 4        abacus  15
# ...         ...  ..
# 40476      zoom  33
# 40477   zooming  29
# 40478     zooms  30
# 40479  zucchini  28
# 40480    zurich  21
#
# [40481 rows x 2 columns]

# %% [markdown]
# 기존 merged 된 file read.

# %%
KE_ELP_path = os.path.join(corpora_dir, 'merged_corpora', 'CSAT_E_final.xlsx')
KE_ELP = pd.read_excel(KE_ELP_path)
KE_ELP
# Out:
#            Word  Length  CSAT_Freq  CSAT_only_Freq  Textbook_only_Freq  \
# 0             a       1    17505.0          9773.0              7732.0
# 1           aah       3        NaN             NaN                 NaN
# 2         aaron       5        7.0             1.0                 6.0
# 3         aback       5        NaN             NaN                 NaN
# 4        abacus       6        NaN             NaN                 NaN
# ...         ...     ...        ...             ...                 ...
# 40476   zooming       7        NaN             NaN                 NaN
# 40477     zooms       5        NaN             NaN                 NaN
# 40478  zucchini       8        NaN             NaN                 NaN
# 40479    zurich       6        NaN             NaN                 NaN
# 40480       NaN       4        NaN             NaN                 NaN
#
#        Freq_HAL     SUBTLWF  Freq_KF    CSAT_RFreq  CSAT_only_RFreq  ...  \
# ...

# %% [markdown]
# merged obs data

# %%
KE_ELP = pd.merge(KE_ELP, ELP_LDT_data, on='Word', how='inner')
KE_ELP.reset_index(drop=True)
KE_ELP.columns
# Out:
# Index(['Word', 'Length', 'CSAT_Freq', 'CSAT_only_Freq', 'Textbook_only_Freq',
#        'Freq_HAL', 'SUBTLWF', 'Freq_KF', 'CSAT_RFreq', 'CSAT_only_RFreq',
#        'Textbook_only_RFreq', 'RFreq_HAL', 'SUBTLRWF', 'RFreq_KF',
#        'Ortho_N_CSAT', 'Ortho_N_CSAT(only)', 'Ortho_N_Textbook(only)',
#        'Ortho_N', 'OLD20_CSAT', 'OLD20_CSAT(only)', 'OLD20_Textbook(only)',
#        'OLD', 'SUBTLCD', 'Concreteness_Rating', 'Age_Of_Acquisition',
#        'Emotional_Valence', 'Emotional_Arousal', 'Emotional_Dominance',
#        'I_Mean_RT', 'I_Zscore', 'I_SD', 'I_NMG_Mean_RT', 'I_NMG_Zscore',
#        'I_NMG_SD', 'POS', 'Obs'],
#       dtype='object')

# %%
renamed_cols = {
    'CSAT_Freq': 'KE_Freq',
    'CSAT_only_Freq': 'KE(EXAM)_Freq',
    'Textbook_only_Freq': 'KE(TEXTBOOK)_Freq',
    'SUBTLWF': 'SUBTLEX_Freq',
    'Freq_KF': 'KF_Freq',
    'CSAT_RFreq': 'KE_RFreq',
    'CSAT_only_RFreq': 'KE(EXAM)_RFreq',
    'Textbook_only_RFreq': 'KE(TEXTBOOK)_RFreq',
    'RFreq_HAL': 'HAL_RFreq',
    'SUBTLRWF': 'SUBTLEX_RFreq',
    'RFreq_KF': 'KF_RFreq',
    'Ortho_N_CSAT': 'KE_Ortho_N',
    'Ortho_N_CSAT(only)': 'KE(EXAM)_Ortho_N',
    'Ortho_N_Textbook(only)': 'KE(TEXTBOOK)_Ortho_N',
    'OLD20_CSAT': 'KE_OLD',
    'OLD20_CSAT(only)': 'KE(EXAM)_OLD',
    'OLD20_Textbook(only)': 'KE(TEXTBOOK)_OLD',
    'I_Mean_RT' : 'LDT_Mean_RT', 
    'I_Zscore' : 'LDT_RT_Zscore',
    'I_SD' : 'LDT_RT_SD', 
    'I_NMG_Mean_RT' : 'NMG_Mean_RT', 
    'I_NMG_Zscore' : 'NMG_RT_Zscore',
    'I_NMG_SD' : 'NMG_RT_SD',
    'Obs': 'LDT_Obs'
}

KE_ELP.rename(columns=renamed_cols, inplace=True)

# %%
KE_ELP.columns
# Out:
# Index(['Word', 'Length', 'KE_Freq', 'KE(EXAM)_Freq', 'KE(TEXTBOOK)_Freq',
#        'Freq_HAL', 'SUBTLEX_Freq', 'KF_Freq', 'KE_RFreq', 'KE(EXAM)_RFreq',
#        'KE(TEXTBOOK)_RFreq', 'HAL_RFreq', 'SUBTLEX_RFreq', 'KF_RFreq',
#        'KE_Ortho_N', 'KE(EXAM)_Ortho_N', 'KE(TEXTBOOK)_Ortho_N', 'Ortho_N',
#        'KE_OLD', 'KE(EXAM)_OLD', 'KE(TEXTBOOK)_OLD', 'OLD', 'SUBTLCD',
#        'Concreteness_Rating', 'Age_Of_Acquisition', 'Emotional_Valence',
#        'Emotional_Arousal', 'Emotional_Dominance', 'LDT_Mean_RT',
#        'LDT_RT_Zscore', 'LDT_RT_SD', 'NMG_Mean_RT', 'NMG_RT_Zscore',
#        'NMG_RT_SD', 'POS', 'LDT_Obs'],
#       dtype='object')

# %%
column_order = ['Word', 'Length', 
                'KE_Freq', 'KE(EXAM)_Freq', 'KE(TEXTBOOK)_Freq', 'Freq_HAL', 'SUBTLEX_Freq', 'KF_Freq', 
                'KE_RFreq', 'KE(EXAM)_RFreq', 'KE(TEXTBOOK)_RFreq', 'HAL_RFreq', 'SUBTLEX_RFreq', 'KF_RFreq',
                'KE_Ortho_N', 'KE(EXAM)_Ortho_N', 'KE(TEXTBOOK)_Ortho_N', 'Ortho_N',
                'KE_OLD', 'KE(EXAM)_OLD', 'KE(TEXTBOOK)_OLD', 'OLD', 
                'SUBTLCD',
                'Concreteness_Rating', 'Age_Of_Acquisition', 'Emotional_Valence', 'Emotional_Arousal', 'Emotional_Dominance', 
                'LDT_Mean_RT', 'LDT_RT_Zscore', 'LDT_RT_SD', 'LDT_Obs',
                'NMG_Mean_RT', 'NMG_RT_Zscore', 'NMG_RT_SD', 
                'POS']

# %%
KE_ELP = KE_ELP[column_order]
KE_ELP.reset_index(drop=True, inplace=True)

# %%
KE_ELP.to_excel(os.path.join(corpora_dir, 'merged_corpora', 'CSAT_E_final(250921).xlsx'), index=False)

# %%
KE_ELP
# Out:
#            Word  Length  KE_Freq  KE(EXAM)_Freq  KE(TEXTBOOK)_Freq  Freq_HAL  \
# 0             a       1  17505.0         9773.0             7732.0  10610626
# 1           aah       3      NaN            NaN                NaN       222
# 2         aaron       5      7.0            1.0                6.0     10806
# 3         aback       5      NaN            NaN                NaN       387
# 4        abacus       6      NaN            NaN                NaN       513
# ...         ...     ...      ...            ...                ...       ...
# 40476   zooming       7      NaN            NaN                NaN       523
# 40477     zooms       5      NaN            NaN                NaN       385
# 40478  zucchini       8      NaN            NaN                NaN       314
# 40479    zurich       6      NaN            NaN                NaN      1770
# 40480       NaN       4      NaN            NaN                NaN     15410
#
# ...

# %%
KE_ELP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40481 entries, 0 to 40480
# Data columns (total 36 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Word                  40480 non-null  object
#  1   Length                40481 non-null  int64
#  2   KE_Freq               16354 non-null  float64
#  3   KE(EXAM)_Freq         14009 non-null  float64
#  4   KE(TEXTBOOK)_Freq     11801 non-null  float64
#  5   Freq_HAL              40481 non-null  int64
#  6   SUBTLEX_Freq          35515 non-null  float64
#  7   KF_Freq               32552 non-null  float64
#  8   KE_RFreq              16354 non-null  float64
#  9   KE(EXAM)_RFreq        14009 non-null  float64
#  10  KE(TEXTBOOK)_RFreq    11801 non-null  float64
#  11  HAL_RFreq             40481 non-null  float64
#  12  SUBTLEX_RFreq         35515 non-null  float64
#  13  KF_RFreq              32552 non-null  float64
# ...

# %%
KE_ELP[['KE_RFreq', 'HAL_RFreq', 'SUBTLEX_RFreq', 'KF_RFreq']].corr()
# Out:
#                KE_RFreq  HAL_RFreq  SUBTLEX_RFreq  KF_RFreq
# KE_RFreq       1.000000   0.989188       0.817785  0.954049
# HAL_RFreq      0.989188   1.000000       0.799306  0.954787
# SUBTLEX_RFreq  0.817785   0.799306       1.000000  0.656533
# KF_RFreq       0.954049   0.954787       0.656533  1.000000

# %%
KE_ELP[['KE_RFreq', 'HAL_RFreq', 'SUBTLEX_RFreq', 'KF_RFreq']].corr(method='spearman')
# Out:
#                KE_RFreq  HAL_RFreq  SUBTLEX_RFreq  KF_RFreq
# KE_RFreq       1.000000   0.729815       0.678321  0.688789
# HAL_RFreq      0.729815   1.000000       0.801952  0.736892
# SUBTLEX_RFreq  0.678321   0.801952       1.000000  0.668395
# KF_RFreq       0.688789   0.736892       0.668395  1.000000

# %%
KE_ELP['KE_Freq'] = KE_ELP['KE_Freq'].fillna(0)
KE_ELP['KE_Freq'].describe()
# Out:
# count    40481.000000
# mean        17.524691
# std        316.267203
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          3.000000
# max      38303.000000
# Name: KE_Freq, dtype: float64

# %%
# 아 어지럽네,, HAL은 freq 범위가 0이 있네 ㅋㅋㅋ 이러면 correlation이 조금 달라지지.
# 찾아보니 corpus 간 비교는 일반적으로 출현하지 않은 단어는 0으로 처리하고 correlation 하라네?
KE_ELP['Freq_HAL'].sort_values(ascending=False)
# Out:
# 36085    23099033
# 36561    12661276
# 24276    11003606
# 1285     10715411
# 0        10610626
#            ...
# 13673           0
# 38072           0
# 13489           0
# 13310           0
# 17515           0
# Name: Freq_HAL, Length: 40481, dtype: int64

# %%
KE_ELP[KE_ELP['Freq_HAL'] == 0]
# Out:
#                Word  Length  KE_Freq  KE(EXAM)_Freq  KE(TEXTBOOK)_Freq  \
# 135     abstractors      11      NaN            NaN                NaN
# 630     affectingly      11      NaN            NaN                NaN
# 742        aggrieve       8      NaN            NaN                NaN
# 755          agleam       6      NaN            NaN                NaN
# 811          airbed       6      NaN            NaN                NaN
# ...             ...     ...      ...            ...                ...
# 39996      wireworm       8      NaN            NaN                NaN
# 40107  woodgraining      12      NaN            NaN                NaN
# 40129   woolworkers      11      NaN            NaN                NaN
# 40145       workbag       7      NaN            NaN                NaN
# 40177  worldshaking      12      NaN            NaN                NaN
#
#        Freq_HAL  SUBTLEX_Freq  KF_Freq  KE_RFreq  KE(EXAM)_RFreq  ...  \
# ...

# %%
np.log10(KE_ELP['KE_RFreq']) + 1
# Out:
# 0        4.392261
# 1             NaN
# 2        0.994196
# 3             NaN
# 4             NaN
#            ...
# 40476         NaN
# 40477         NaN
# 40478         NaN
# 40479         NaN
# 40480         NaN
# Name: KE_RFreq, Length: 40481, dtype: float64

# %% [markdown]
# behvaior data 분석에 사용되지 않

# %% [markdown]
# behavior exp data 있는 word 만 추출

# %%
# 아래의 값들이 drop 대상.
ELP_LDT_data[ELP_LDT_data['SUBTLWF'] == '#']
# Out:
#               Word  Length SUBTLWF I_Mean_RT I_Zscore     I_SD Obs  \
# 10       abasement       9       #  1037.059    0.923  311.845  17
# 11           abash       5       #   748.714    0.229  194.366  21
# 26             Abe       3       #   820.667    0.075  254.987  33
# 29          Abel's       6       #   840.143    0.196  333.080  28
# 83      abridgment      10       #  1152.611    0.873  484.354  18
# ...            ...     ...     ...       ...      ...      ...  ..
# 40415      young's       7       #   844.483    0.038  435.469  29
# 40418  youngster's      11       #   763.156   -0.125  260.448  32
# 40420       you're       6       #   679.091   -0.288  174.945  33
# 40427       you've       6       #   725.903   -0.352  255.048  31
# 40429      Yucatan       7       #   813.542    0.310  237.189  24
#
#        I_Mean_Accuracy
# 10                0.53
# 11                0.68
# 26                1.00
# 29                0.82
# 83                0.60
# ...

# %%
# drop any row which has '#' in the columns_to_check
columns_to_check = ELP_LDT_data.columns.drop(['Word', 'Length', 'I_Mean_Accuracy'])
mask = (ELP_LDT_data[columns_to_check].isin(['#'])).any(axis=1)
ELP_LDT_data = ELP_LDT_data[~mask].reset_index(drop=True)
ELP_LDT_data
# Out:
#            Word  Length    SUBTLWF I_Mean_RT I_Zscore     I_SD Obs  \
# 0             a       1  20415.270   798.917   -0.013  333.849  24
# 1           aah       3     52.710   816.429    0.214  186.029  21
# 2         Aaron       5     14.650   736.062   -0.111  289.010  32
# 3         aback       5      0.290   796.267    0.110  171.607  15
# 4        abacus       6      0.240   964.400    0.655  488.996  15
# ...         ...     ...        ...       ...      ...      ...  ..
# 35495      zoom       4      3.550   549.758   -0.762   97.649  33
# 35496   zooming       7      0.630   709.690   -0.293  283.106  29
# 35497     zooms       5      0.060   666.933   -0.476  232.109  30
# 35498  zucchini       8      0.960   848.679    0.239  259.819  28
# 35499    Zurich       6      2.430   763.000    0.091  184.257  21
#
#        I_Mean_Accuracy
# 0                 0.73
# 1                 0.62
# 2                 0.97
# 3                 0.45
# 4                 0.47
# ...

# %%
# change columns dtype
ELP_LDT_data['SUBTLWF'] = ELP_LDT_data['SUBTLWF'].astype('float')
ELP_LDT_data['I_Mean_RT'] = ELP_LDT_data['I_Mean_RT'].astype('float')
ELP_LDT_data['I_Zscore'] = ELP_LDT_data['I_Zscore'].astype('float')
ELP_LDT_data['I_SD'] = ELP_LDT_data['I_SD'].astype('float')
ELP_LDT_data['Obs'] = ELP_LDT_data['Obs'].astype('float')

# %%
# applying lower to Word 
ELP_LDT_data['Word'] = ELP_LDT_data['Word'].str.lower()

# %%
ELP_LDT_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35500 entries, 0 to 35499
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Word             35499 non-null  object
#  1   Length           35500 non-null  int64
#  2   SUBTLWF          35500 non-null  float64
#  3   I_Mean_RT        35500 non-null  float64
#  4   I_Zscore         35500 non-null  float64
#  5   I_SD             35500 non-null  float64
#  6   Obs              35500 non-null  float64
#  7   I_Mean_Accuracy  35500 non-null  float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 2.2+ MB

# %%
ELP_LDT_data.to_excel(os.path.join(corpora_dir, 'behavior-exp', 'ELP-LDT(preprocessed).xlsx'), index=False)

# %% [markdown]
# # Merging with KE corpora(depreted): already exist in data files.

# %%
KE_E_Lex_path = os.path.join(corpora_dir, 'merged_corpora', 'CSAT_E_final.xlsx')
KE_E_Lex = pd.read_excel(KE_E_Lex_path)
ELP_LDT_path = os.path.join(corpora_dir, 'behavior-exp', 'ELP-LDT(preprocessed).xlsx')
ELP_LDT_data = pd.read_excel(ELP_LDT_path)
KE_E_Lex.head()
# Out:
#      Word  Length  CSAT_Freq  CSAT_only_Freq  Textbook_only_Freq  Freq_HAL  \
# 0       a       1    17505.0          9773.0              7732.0  10610626
# 1     aah       3        NaN             NaN                 NaN       222
# 2   aaron       5        7.0             1.0                 6.0     10806
# 3   aback       5        NaN             NaN                 NaN       387
# 4  abacus       6        NaN             NaN                 NaN       513
#
#       SUBTLWF  Freq_KF    CSAT_RFreq  CSAT_only_RFreq  ...  Emotional_Valence  \
# 0  1041178.77  23237.0  24675.191037     23843.796660  ...                NaN
# 1     2688.21      1.0           NaN              NaN  ...                NaN
# 2      747.15      7.0      9.867257         2.439762  ...                NaN
# 3       14.79      2.0           NaN              NaN  ...                NaN
# 4       12.24      NaN           NaN              NaN  ...                NaN
#
# ...

# %%
# filter the KE words
mask = ~KE_E_Lex['CSAT_Freq'].isna()
KE = KE_E_Lex[mask].reset_index(drop=True)
KE
# Out:
#              Word  Length  CSAT_Freq  CSAT_only_Freq  Textbook_only_Freq  \
# 0               a       1    17505.0          9773.0              7732.0
# 1           aaron       5        7.0             1.0                 6.0
# 2         abandon       7        7.0             5.0                 2.0
# 3       abandoned       9       12.0             5.0                 7.0
# 4      abandoning      10        3.0             3.0                 NaN
# ...           ...     ...        ...             ...                 ...
# 16349     zombies       7        3.0             NaN                 3.0
# 16350        zone       4       19.0             6.0                13.0
# 16351       zones       5       17.0             8.0                 9.0
# 16352         zoo       3       31.0            21.0                10.0
# 16353   zoologist       9        2.0             2.0                 NaN
#
#        Freq_HAL     SUBTLWF  Freq_KF    CSAT_RFreq  CSAT_only_RFreq  ...  \
# ...

# %% [markdown]
# # reduce file

# %%
KE_E_Lex_path = os.path.join(corpora_dir, 'merged_corpora', 'CSAT_E_final.xlsx')
KE_E_Lex = pd.read_excel(KE_E_Lex_path)
ELP_LDT_path = os.path.join(corpora_dir, 'behavior-exp', 'ELP-LDT(preprocessed).xlsx')
ELP_LDT_data = pd.read_excel(ELP_LDT_path)
KE_E_Lex.columns, ELP_LDT_data.columns
# Out:
# (Index(['Word', 'Length', 'CSAT_Freq', 'CSAT_only_Freq', 'Textbook_only_Freq',
#         'Freq_HAL', 'SUBTLWF', 'Freq_KF', 'CSAT_RFreq', 'CSAT_only_RFreq',
#         'Textbook_only_RFreq', 'RFreq_HAL', 'SUBTLRWF', 'RFreq_KF',
#         'Ortho_N_CSAT', 'Ortho_N_CSAT(only)', 'Ortho_N_Textbook(only)',
#         'Ortho_N', 'OLD20_CSAT', 'OLD20_CSAT(only)', 'OLD20_Textbook(only)',
#         'OLD', 'SUBTLCD', 'Concreteness_Rating', 'Age_Of_Acquisition',
#         'Emotional_Valence', 'Emotional_Arousal', 'Emotional_Dominance',
#         'I_Mean_RT', 'I_Zscore', 'I_SD', 'I_NMG_Mean_RT', 'I_NMG_Zscore',
#         'I_NMG_SD', 'POS'],
#        dtype='object'),
#  Index(['Word', 'Length', 'SUBTLWF', 'I_Mean_RT', 'I_Zscore', 'I_SD', 'Obs',
#         'I_Mean_Accuracy'],
#        dtype='object'))

# %% [markdown]
# ## attach the additional data

# %%
# ELP_LDT_data[['Word', 'Obs', 'I_Mean_Accuracy']]
ELP_LDT_data = pd.merge(KE_E_Lex, ELP_LDT_data[['Word', 'Obs', 'I_Mean_Accuracy']], on='Word', how='left')
ELP_LDT_data
# Out:
#            Word  Length  CSAT_Freq  CSAT_only_Freq  Textbook_only_Freq  \
# 0             a       1    17505.0          9773.0              7732.0
# 1           aah       3        NaN             NaN                 NaN
# 2         aaron       5        7.0             1.0                 6.0
# 3         aback       5        NaN             NaN                 NaN
# 4        abacus       6        NaN             NaN                 NaN
# ...         ...     ...        ...             ...                 ...
# 40476   zooming       7        NaN             NaN                 NaN
# 40477     zooms       5        NaN             NaN                 NaN
# 40478  zucchini       8        NaN             NaN                 NaN
# 40479    zurich       6        NaN             NaN                 NaN
# 40480       NaN       4        NaN             NaN                 NaN
#
#        Freq_HAL     SUBTLWF  Freq_KF    CSAT_RFreq  CSAT_only_RFreq  ...  \
# ...

# %%
behavior_cols = ['Word', 'Length', 'CSAT_Freq', 'SUBTLWF', 
                'I_Mean_RT', 'I_Zscore', 'I_SD', 'Obs', 'I_Mean_Accuracy']
ELP_LDT_data = ELP_LDT_data[behavior_cols]
ELP_LDT_data
# Out:
#            Word  Length  CSAT_Freq     SUBTLWF  I_Mean_RT  I_Zscore     I_SD  \
# 0             a       1    17505.0  1041178.77    798.917    -0.013  333.849
# 1           aah       3        NaN     2688.21    816.429     0.214  186.029
# 2         aaron       5        7.0      747.15    736.062    -0.111  289.010
# 3         aback       5        NaN       14.79    796.267     0.110  171.607
# 4        abacus       6        NaN       12.24    964.400     0.655  488.996
# ...         ...     ...        ...         ...        ...       ...      ...
# 40476   zooming       7        NaN       32.13    709.690    -0.293  283.106
# 40477     zooms       5        NaN        3.06    666.933    -0.476  232.109
# 40478  zucchini       8        NaN       48.96    848.679     0.239  259.819
# 40479    zurich       6        NaN      123.93    763.000     0.091  184.257
# 40480       NaN       4        NaN       27.03    703.467    -0.278  168.922
#
#         Obs  I_Mean_Accuracy
# ...

# %%
mask = ELP_LDT_data[['CSAT_Freq', 'SUBTLWF', 'I_Mean_RT', 'I_Zscore', 'I_SD', 'I_Mean_Accuracy']].isna().any(axis=1)
ELP_LDT_data = ELP_LDT_data[~mask].reset_index(drop=True)
ELP_LDT_data
# Out:
#               Word  Length  CSAT_Freq     SUBTLWF  I_Mean_RT  I_Zscore  \
# 0                a       1    17505.0  1041178.77    798.917    -0.013
# 1          abandon       7        7.0      413.10    695.719    -0.312
# 2        abandoned       9       12.0      677.79    860.774    -0.095
# 3       abandoning      10        3.0       86.19    740.545    -0.111
# 4      abandonment      11        2.0       48.96    771.088    -0.002
# ...            ...     ...        ...         ...        ...       ...
# 15212      zombies       7        3.0      114.75    737.562    -0.148
# 15213         zone       4       19.0     1026.12    577.727    -0.771
# 15214        zones       5       17.0       89.76    605.229    -0.673
# 15215          zoo       3       31.0      696.15    572.562    -0.793
# 15216    zoologist       9        2.0       12.24    714.088    -0.118
#
#           I_SD   Obs  I_Mean_Accuracy
# 0      333.849  24.0             0.73
# ...

# %%
ELP_LDT_data.rename(columns={'CSAT_Freq': 'KE_Freq'}, inplace=True)
ELP_LDT_data.to_excel(os.path.join(corpora_dir, 'behavior-exp', 'ELP-LDT(preprocessed).xlsx'), index=False)

# %%
ELP_LDT_data
# Out:
#               Word  Length  KE_Freq     SUBTLWF  I_Mean_RT  I_Zscore     I_SD  \
# 0                a       1  17505.0  1041178.77    798.917    -0.013  333.849
# 1          abandon       7      7.0      413.10    695.719    -0.312  220.412
# 2        abandoned       9     12.0      677.79    860.774    -0.095  447.558
# 3       abandoning      10      3.0       86.19    740.545    -0.111  288.435
# 4      abandonment      11      2.0       48.96    771.088    -0.002  229.526
# ...            ...     ...      ...         ...        ...       ...      ...
# 15212      zombies       7      3.0      114.75    737.562    -0.148  197.720
# 15213         zone       4     19.0     1026.12    577.727    -0.771  165.732
# 15214        zones       5     17.0       89.76    605.229    -0.673  153.891
# 15215          zoo       3     31.0      696.15    572.562    -0.793  180.819
# 15216    zoologist       9      2.0       12.24    714.088    -0.118  165.017
#
#         Obs  I_Mean_Accuracy
# ...

# %%
ELP_LDT_data['R_SUBTLWF'] = ELP_LDT_data['SUBTLWF'] * (1000. / 5100.)

# %%
ELP_LDT_data['R_KE_Freq'] = ELP_LDT_data['KE_Freq'] * (1000. / 83.0)

# %%
ELP_LDT_data.sort_values(by='R_SUBTLWF', ascending=False, inplace=True)
ELP_LDT_data.reset_index(drop=True, inplace=True)
ELP_LDT_data
# Out:
#                  Word  Length  KE_Freq     SUBTLWF  I_Mean_RT  I_Zscore  \
# 0                 you       3  10292.0  2134713.12    615.212    -0.597
# 1                 the       3  38303.0  1501908.18    600.194    -0.681
# 2                  to       2  21665.0  1156569.84    551.273    -0.786
# 3                   a       1  17505.0  1041178.77    798.917    -0.013
# 4                  it       2   8679.0   963711.81    566.848    -0.865
# ...               ...     ...      ...         ...        ...       ...
# 15212      outweighed      10      1.0        1.02    764.433    -0.026
# 15213       overcrowd       9      1.0        1.02    782.516    -0.092
# 15214      fallacious      10      1.0        1.02    819.815     0.335
# 15215       heritages       9      1.0        1.02    828.690     0.154
# 15216  approximations      14      1.0        1.02    923.767     0.292
#
#           I_SD   Obs  I_Mean_Accuracy  R_SUBTLWF      R_KE_Freq
# ...

# %%
ELP_LDT_data[['R_SUBTLWF', 'R_KE_Freq']].corr()
# Out:
#            R_SUBTLWF  R_KE_Freq
# R_SUBTLWF   1.000000   0.843043
# R_KE_Freq   0.843043   1.000000

# %%
ELP_LDT_data.shape[0]
# Out:
# 15217

# %%
ELP_LDT_data[['R_SUBTLWF', 'R_KE_Freq']][:int(ELP_LDT_data.shape[0]/2)].corr()
# Out:
#            R_SUBTLWF  R_KE_Freq
# R_SUBTLWF   1.000000   0.842008
# R_KE_Freq   0.842008   1.000000

# %%
ELP_LDT_data[['R_SUBTLWF', 'R_KE_Freq']][:int(ELP_LDT_data.shape[0]/2)].corr(method='spearman')
# Out:
#            R_SUBTLWF  R_KE_Freq
# R_SUBTLWF   1.000000   0.628804
# R_KE_Freq   0.628804   1.000000

# %%
ELP_LDT_data[['R_SUBTLWF', 'R_KE_Freq']][int(ELP_LDT_data.shape[0]/2):].corr()
# Out:
#            R_SUBTLWF  R_KE_Freq
# R_SUBTLWF   1.000000   0.269901
# R_KE_Freq   0.269901   1.000000

# %%
ELP_LDT_data[['R_SUBTLWF', 'R_KE_Freq']][int(ELP_LDT_data.shape[0]/2):].corr(method='spearman')
# Out:
#            R_SUBTLWF  R_KE_Freq
# R_SUBTLWF   1.000000   0.352928
# R_KE_Freq   0.352928   1.000000
